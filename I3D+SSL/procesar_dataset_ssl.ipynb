# %%
import copy
from scipy.spatial.distance import euclidean
import json
import numpy as np
from fastdtw import fastdtw
import os
import cv2
import matplotlib.pyplot as plt
from  IPython.display import clear_output
import copy
import math
import time 

import imgaug.augmenters as iaa
from imgaug.augmentables.bbs import BoundingBox, BoundingBoxesOnImage
import imgaug as ia

#pip install imgaug
#pip install fastdtw

# %% [markdown]
# # Process Halfs

# %%
class VideoDatasetSSL():

    def __init__(self, path_bar_trayectory, output_path, videos_path, desired_length_frames, already = False):
        super(VideoDatasetSSL, self).__init__()
        self.path_bar_trayectory = path_bar_trayectory
        self.output_path = output_path
        self.videos_path = videos_path
        self.already = already
        self.desired_length = desired_length_frames
        self.trayectories = {}
        self.videos_files = []
        self.dtw_path = {}
        self.get_all_trayectories()

    def get_all_trayectories(self):
        files = [f for f in os.listdir(self.videos_path)]
        files = sorted(files)  
        self.videos_files = files
        for file in files:
            name_ = file.split(".")[0]
            path = os.path.join(self.path_bar_trayectory, name_+".json")
            f = open(path)
            data = json.load(f) 
            trayectory_ = self.get_trayectory(data)
            self.trayectories[name_] = trayectory_
    
    def get_size(self):
        return len(self.videos_files)

    def obtener_std(self):
        count = []
        for video_name in self.videos_files:
            path_to_video = os.path.join(self.videos_path, video_name)
            cap= cv2.VideoCapture(path_to_video)
            totalframecount= int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
            count.append(totalframecount)
        count = np.array(count)
        print('Std: {0}, Mean: {1}, Max: {2}, Min: {3}'.format(np.std(count), np.mean(count), np.max(count), np.min(count)))

    def normalizar_posiciones_y(self, posiciones_y):
        pos_min = min(posiciones_y)
        pos_max = max(posiciones_y)
        amplitud_vertical = pos_max - pos_min

        if amplitud_vertical == 0:
            factor_escala = 1
        else:
            factor_escala = 1 / amplitud_vertical

        posiciones_y_normalizadas = np.array([[(pos - pos_min) * factor_escala] for pos in posiciones_y])
        return posiciones_y_normalizadas
    
    
    def rellenar_trayectorias(self,trayectorias):
        filled_trayectorias = np.copy(trayectorias)

        for i in range(len(trayectorias)):
            if np.isnan(trayectorias[i]):
                prev_index = i - 1
                next_index = i + 1

                while prev_index >= 0 and np.isnan(trayectorias[prev_index]):
                    prev_index -= 1
                while next_index < len(trayectorias) and np.isnan(trayectorias[next_index]):
                    next_index += 1

                if prev_index >= 0 and next_index < len(trayectorias):
                    filled_trayectorias[i] = (trayectorias[prev_index] + trayectorias[next_index]) / 2
                elif prev_index >= 0:
                    filled_trayectorias[i] = trayectorias[prev_index]
                elif next_index < len(trayectorias):
                    filled_trayectorias[i] = trayectorias[next_index]
                else:
                    filled_trayectorias[i] = 1

        return filled_trayectorias

    
    def get_trayectory(self, data):
        if self.already == False:
            vertical_trayectory = np.zeros(len(data))
            trayectoria_normalizada = []
            for cnt, _ in enumerate(data):
                if len(data[cnt][0]) > 0:
                    x1,y1,x2,y2,_ = data[cnt][0][0]
                    center_x, center_y = int(x1 + (x2-x1)/2) , int(y1 + (y2 - y1)/2)
                    vertical_trayectory[cnt] = center_y
                else:
                    indices = np.nonzero(vertical_trayectory)[0]
                    if len(indices) > 0:
                        j = indices[indices < cnt][-1]
                        value = vertical_trayectory[j]
                        vertical_trayectory[cnt] = value
        else:
            vertical_trayectory = data
            vertical_trayectory = self.rellenar_trayectorias(vertical_trayectory)
        trayectoria_normalizada = self.normalizar_posiciones_y(vertical_trayectory)
        return trayectoria_normalizada
    
    def video_alignment(self, video1_embeddings, video2_embeddings):
        distance, path = fastdtw(video1_embeddings, video2_embeddings, dist=euclidean)
        return path, distance
    
    def find_lowest_point_index(self, y_trajectory):
        return np.argmin(y_trajectory)

    def split_trajectory(self, y_trajectory):
        lowest_point_index = self.find_lowest_point_index(y_trajectory)
        first_half = y_trajectory[:lowest_point_index]
        second_half = y_trajectory[lowest_point_index:]
        if lowest_point_index == 0 or lowest_point_index == len(y_trajectory):
            half_length = len(y_trajectory) // 2
            first_half = y_trajectory[:half_length]
            second_half = y_trajectory[half_length:]
        return first_half, second_half

    def save_frames(self, frames, output_path):
        for j in range(len(frames)):
            image_array = np.array(frames[j])
            out_path = output_path+"/{}".format(str(j).zfill(3)) +".jpg"
            cv2.imwrite(out_path, image_array)

    def save_sync_videos(self, path, frames, output_path):
        f_h_anchor = []
        s_h_negative = []
        
        for i,j in path:
            frame1 = frames[i]
            frame2 = frames[len(frames)-j-1]
            f_h_anchor.append(frame1)
            s_h_negative.append(frame2)

        p1 = output_path+"/f_h"
        p2 = output_path+"/s_h"

        try:
            os.mkdir(p1)
            os.mkdir(p2)
        except:
            print("duplicated")

        #print(p1,p2)
        self.save_frames(f_h_anchor, p1)
        self.save_frames(s_h_negative,p2)
    
    def interpolate_trajectory(self, _trajectory, num_frames = 200):
        trajectory = []
        scale_factor = len(_trajectory) / num_frames
        
        for i in range(num_frames):
            original_frame_idx = int(i * scale_factor)
            y = _trajectory[original_frame_idx]
            if original_frame_idx < len(_trajectory) - 1:
                next_y = _trajectory[original_frame_idx + 1]
                interpolated_y = (y + next_y) / 2
                trajectory.append(interpolated_y)
            else:
                trajectory.append(y)
        
        return trajectory
    
    def load_images(self,path):
        files = os.listdir(path)
        files.sort(key=lambda x: int(x.split('.')[0]))
        #print(files)
        frames = [cv2.imread(path+"/"+name, cv2.COLOR_BGR2RGB) for name in files]
        return frames
    
    def obtener_mitad(self, idx):
        video_name = self.videos_files[idx]
        name_ = video_name.split('.')[0]
        #path_ = os.path.join(self.input_path, video_name)
        path_ = os.path.join(self.output_path, name_)
        path_fh = os.path.join(path_, "_f_h")
        path_sh = os.path.join(path_, "_s_h")
        f1 = self.load_images(path_fh)
        f2 = self.load_images(path_sh)

        for i in range(len(f1)):
            frame = np.hstack((f1[i], f2[i]))
            clear_output(wait=True)
            plt.imshow(frame)
            plt.show()
    
    def adjust_points_for_horizontal_flip(self,points, frame_width):
        points_2d = np.reshape(points, (-1, 2))
        points_2d[:, 0] = frame_width - points_2d[:, 0]
        adjusted_points = points_2d.flatten()

    def load_video(self, path):
        video  = cv2.VideoCapture(path)
        success = True
        count = 1
        frames = []
        while success:
            success, frame = video.read()
            if success:
                frame = cv2.resize(frame, (480,480), cv2.INTER_AREA)
                frames.append(frame)
                count+=1
            else:
                break
        return frames

    def __getitem__(self, idx):
        video_name = self.videos_files[idx]
        print(video_name)
        name_ = video_name.split('.')[0]
        trajectory = self.trayectories[name_]
        path_to_video = os.path.join(self.videos_path, video_name)
        frames = self.load_video(path_to_video)
        first_half, second_half = self.split_trajectory(trajectory)
        second_half = np.flip(second_half)
        path, cost = self.video_alignment(first_half,second_half)
        
        tam = math.ceil(len(path) / self.desired_length)
        final_path = []
        for i in range(0,len(path), tam):
            final_path.append(path[i])
        
        while len(final_path) < self.desired_length:
            final_path.append(path[-1])

        path_ = os.path.join(self.output_path, name_)
        try:
            os.mkdir(path_)
        except:
            pass
        self.save_sync_videos(final_path, frames, path_)

# %%
path_bar_trayectory = "./FAQA/Squat/Unlabeled/bar_trajectories_raw/"
output_path = "./FAQA/Squat/Unlabeled/Images/"
videos_path = "./FAQA/Squat/Unlabeled/videos/"
desired_length_frames = 16

SSL_dataset = VideoDatasetSSL(path_bar_trayectory, output_path, videos_path, desired_length_frames, True)
#SSL_dataset.obtener_mitad(0) Unicamente para mostrar los videos alineados

# %%
#SSL_dataset.obtener_std()

# %%
#Generate all frames
n = SSL_dataset.get_size()
for i in range(n):
    SSL_dataset.__getitem__(i)  
    print("El video "+ str(i) + " ha sido procesado")
# Out:
# 25195_3.mp4
# duplicated
# El video 0 ha sido procesado
# 25706_5.mp4
# duplicated
# El video 1 ha sido procesado
# 25707_3.mp4
# El video 2 ha sido procesado
# 25708_2.mp4
# El video 3 ha sido procesado
# 25709_1.mp4
# El video 4 ha sido procesado
# 25710_4.mp4
# El video 5 ha sido procesado
# 25711_2.mp4
# El video 6 ha sido procesado
# 25712_4.mp4
# El video 7 ha sido procesado
# 25713_3.mp4
# El video 8 ha sido procesado
# 25714_1.mp4
# El video 9 ha sido procesado
# 25715_3.mp4
# El video 10 ha sido procesado
# 25716_2.mp4
# El video 11 ha sido procesado
# 25717_2.mp4
# El video 12 ha sido procesado
# 25718_1.mp4
# El video 13 ha sido procesado
# 25719_2.mp4
# El video 14 ha sido procesado
# 25721_1.mp4
# El video 15 ha sido procesado
# 25722_3.mp4
# El video 16 ha sido procesado
# 25723_2.mp4
# El video 17 ha sido procesado
# 25724_1.mp4
# El video 18 ha sido procesado
# 25725_5.mp4
# El video 19 ha sido procesado
# 25726_2.mp4
# El video 20 ha sido procesado
# 25727_1.mp4
# El video 21 ha sido procesado
# 25728_1.mp4
# El video 22 ha sido procesado
# 25731_2.mp4
# El video 23 ha sido procesado
# 25732_1.mp4
# El video 24 ha sido procesado
# 25733_1.mp4
# El video 25 ha sido procesado
# 25734_3.mp4
# El video 26 ha sido procesado
# 25735_1.mp4
# El video 27 ha sido procesado
# 25736_8.mp4
# El video 28 ha sido procesado
# 25737_1.mp4
# El video 29 ha sido procesado
# 25738_3.mp4
# El video 30 ha sido procesado
# 25739_1.mp4
# El video 31 ha sido procesado
# 25741_1.mp4
# El video 32 ha sido procesado
# 25742_3.mp4
# El video 33 ha sido procesado
# 25743_5.mp4
# El video 34 ha sido procesado
# 25744_2.mp4
# El video 35 ha sido procesado
# 25746_1.mp4
# El video 36 ha sido procesado
# 25747_3.mp4
# El video 37 ha sido procesado
# 25748_2.mp4
# El video 38 ha sido procesado
# 25750_4.mp4
# El video 39 ha sido procesado
# 25751_1.mp4
# El video 40 ha sido procesado
# 25752_1.mp4
# El video 41 ha sido procesado
# 25754_1.mp4
# El video 42 ha sido procesado
# 25755_2.mp4
# El video 43 ha sido procesado
# 25756_3.mp4
# El video 44 ha sido procesado
# 25757_1.mp4
# El video 45 ha sido procesado
# 25759_1.mp4
# El video 46 ha sido procesado
# 25760_7.mp4
# El video 47 ha sido procesado
# 25761_2.mp4
# El video 48 ha sido procesado
# 25762_1.mp4
# El video 49 ha sido procesado
# 25763_1.mp4
# El video 50 ha sido procesado
# 25765_1.mp4
# El video 51 ha sido procesado
# 25768_1.mp4
# El video 52 ha sido procesado
# 25769_6.mp4
# El video 53 ha sido procesado
# 25770_4.mp4
# El video 54 ha sido procesado
# 25771_1.mp4
# El video 55 ha sido procesado
# 25773_1.mp4
# El video 56 ha sido procesado
# 25774_1.mp4
# El video 57 ha sido procesado
# 25778_1.mp4
# El video 58 ha sido procesado
# 25779_1.mp4
# El video 59 ha sido procesado
# 25780_1.mp4
# El video 60 ha sido procesado
# 25784_5.mp4
# El video 61 ha sido procesado
# 25785_2.mp4
# El video 62 ha sido procesado
# 25786_5.mp4
# El video 63 ha sido procesado
# 25787_2.mp4
# El video 64 ha sido procesado
# 25789_3.mp4
# El video 65 ha sido procesado
# 25790_1.mp4
# El video 66 ha sido procesado
# 25791_10.mp4
# El video 67 ha sido procesado
# 25792_1.mp4
# El video 68 ha sido procesado
# 25793_1.mp4
# El video 69 ha sido procesado
# 25794_2.mp4
# El video 70 ha sido procesado
# 25795_3.mp4
# El video 71 ha sido procesado
# 25797_1.mp4
# El video 72 ha sido procesado
# 25798_1.mp4
# El video 73 ha sido procesado
# 25799_2.mp4
# El video 74 ha sido procesado
# 25801_9.mp4
# El video 75 ha sido procesado
# 25803_3.mp4
# El video 76 ha sido procesado
# 25805_1.mp4
# El video 77 ha sido procesado
# 25806_3.mp4
# El video 78 ha sido procesado
# 25807_1.mp4
# El video 79 ha sido procesado
# 25808_1.mp4
# El video 80 ha sido procesado
# 25811_1.mp4
# El video 81 ha sido procesado
# 25812_3.mp4
# El video 82 ha sido procesado
# 25813_1.mp4
# El video 83 ha sido procesado
# 25814_1.mp4
# El video 84 ha sido procesado
# 25815_1.mp4
# El video 85 ha sido procesado
# 25816_3.mp4
# El video 86 ha sido procesado
# 25817_3.mp4
# El video 87 ha sido procesado
# 25819_10.mp4
# El video 88 ha sido procesado
# 25820_2.mp4
# El video 89 ha sido procesado
# 25821_2.mp4
# El video 90 ha sido procesado
# 25822_4.mp4
# El video 91 ha sido procesado
# 25823_3.mp4
# El video 92 ha sido procesado
# 25825_1.mp4
# El video 93 ha sido procesado
# 25826_1.mp4
# El video 94 ha sido procesado
# 25827_1.mp4
# El video 95 ha sido procesado
# 25828_1.mp4
# El video 96 ha sido procesado
# 25829_2.mp4
# El video 97 ha sido procesado
# 25830_2.mp4
# El video 98 ha sido procesado
# 25831_4.mp4
# El video 99 ha sido procesado
# 25832_2.mp4
# El video 100 ha sido procesado
# 25833_5.mp4
# El video 101 ha sido procesado
# 25834_1.mp4
# El video 102 ha sido procesado
# 25836_1.mp4
# El video 103 ha sido procesado
# 25837_3.mp4
# El video 104 ha sido procesado
# 25838_2.mp4
# El video 105 ha sido procesado
# 25839_1.mp4
# El video 106 ha sido procesado
# 25840_2.mp4
# El video 107 ha sido procesado
# 25841_1.mp4
# El video 108 ha sido procesado
# 25842_4.mp4
# El video 109 ha sido procesado
# 25843_3.mp4
# El video 110 ha sido procesado
# 25844_2.mp4
# El video 111 ha sido procesado
# 25845_3.mp4
# El video 112 ha sido procesado
# 25846_1.mp4
# El video 113 ha sido procesado
# 25847_1.mp4
# El video 114 ha sido procesado
# 25848_6.mp4
# El video 115 ha sido procesado
# 25849_2.mp4
# El video 116 ha sido procesado
# 25850_1.mp4
# El video 117 ha sido procesado
# 25851_1.mp4
# El video 118 ha sido procesado
# 25852_1.mp4
# El video 119 ha sido procesado
# 25853_2.mp4
# El video 120 ha sido procesado
# 25854_1.mp4
# El video 121 ha sido procesado
# 25855_2.mp4
# El video 122 ha sido procesado
# 25856_1.mp4
# El video 123 ha sido procesado
# 25857_1.mp4
# El video 124 ha sido procesado
# 25859_1.mp4
# El video 125 ha sido procesado
# 25860_2.mp4
# El video 126 ha sido procesado
# 25861_1.mp4
# El video 127 ha sido procesado
# 25862_3.mp4
# El video 128 ha sido procesado
# 25863_2.mp4
# El video 129 ha sido procesado
# 25864_1.mp4
# El video 130 ha sido procesado
# 25865_1.mp4
# El video 131 ha sido procesado
# 25866_1.mp4
# El video 132 ha sido procesado
# 25867_1.mp4
# El video 133 ha sido procesado
# 25868_3.mp4
# El video 134 ha sido procesado
# 25869_1.mp4
# El video 135 ha sido procesado
# 25871_1.mp4
# El video 136 ha sido procesado
# 25872_1.mp4
# El video 137 ha sido procesado
# 25873_4.mp4
# El video 138 ha sido procesado
# 25874_1.mp4
# El video 139 ha sido procesado
# 25875_1.mp4
# El video 140 ha sido procesado
# 25876_4.mp4
# El video 141 ha sido procesado
# 25877_4.mp4
# El video 142 ha sido procesado
# 25879_1.mp4
# El video 143 ha sido procesado
# 25880_5.mp4
# El video 144 ha sido procesado
# 25881_1.mp4
# El video 145 ha sido procesado
# 25882_10.mp4
# El video 146 ha sido procesado
# 25883_3.mp4
# El video 147 ha sido procesado
# 25884_4.mp4
# El video 148 ha sido procesado
# 25885_2.mp4
# El video 149 ha sido procesado
# 25886_1.mp4
# El video 150 ha sido procesado
# 25887_1.mp4
# El video 151 ha sido procesado
# 25889_2.mp4
# El video 152 ha sido procesado
# 25890_5.mp4
# El video 153 ha sido procesado
# 25891_3.mp4
# El video 154 ha sido procesado
# 25892_4.mp4
# El video 155 ha sido procesado
# 25895_1.mp4
# El video 156 ha sido procesado
# 25896_1.mp4
# El video 157 ha sido procesado
# 25897_8.mp4
# El video 158 ha sido procesado
# 25898_3.mp4
# El video 159 ha sido procesado
# 25899_2.mp4
# El video 160 ha sido procesado
# 25900_1.mp4
# El video 161 ha sido procesado
# 25901_1.mp4
# El video 162 ha sido procesado
# 25902_1.mp4
# El video 163 ha sido procesado
# 25903_7.mp4
# El video 164 ha sido procesado
# 25904_5.mp4
# El video 165 ha sido procesado
# 25905_3.mp4
# El video 166 ha sido procesado
# 25906_1.mp4
# El video 167 ha sido procesado
# 25907_2.mp4
# El video 168 ha sido procesado
# 25908_1.mp4
# El video 169 ha sido procesado
# 25909_1.mp4
# El video 170 ha sido procesado
# 25910_2.mp4
# El video 171 ha sido procesado
# 25911_2.mp4
# El video 172 ha sido procesado
# 25912_1.mp4
# El video 173 ha sido procesado
# 32897_3.mp4
# El video 174 ha sido procesado
# 32899_1.mp4
# El video 175 ha sido procesado
# 32903_8.mp4
# El video 176 ha sido procesado
# 32907_3.mp4
# El video 177 ha sido procesado
# 32918_1.mp4
# El video 178 ha sido procesado
# 32921_4.mp4
# El video 179 ha sido procesado
# 32922_3.mp4
# El video 180 ha sido procesado
# 32924_3.mp4
# El video 181 ha sido procesado
# 32927_3.mp4
# El video 182 ha sido procesado
# 32936_3.mp4
# El video 183 ha sido procesado
# 32939_2.mp4
# El video 184 ha sido procesado
# 32941_5.mp4
# El video 185 ha sido procesado
# 32945_1.mp4
# El video 186 ha sido procesado
# 32946_1.mp4
# El video 187 ha sido procesado
# 32956_15.mp4
# El video 188 ha sido procesado
# 32964_1.mp4
# El video 189 ha sido procesado
# 32970_4.mp4
# El video 190 ha sido procesado
# 32971_2.mp4
# El video 191 ha sido procesado
# 32975_6.mp4
# El video 192 ha sido procesado
# 32977_1.mp4
# El video 193 ha sido procesado
# 32979_1.mp4
# El video 194 ha sido procesado
# 32987_5.mp4
# El video 195 ha sido procesado
# 32990_6.mp4
# El video 196 ha sido procesado
# 32991_2.mp4
# El video 197 ha sido procesado
# 32994_1.mp4
# El video 198 ha sido procesado
# 32995_3.mp4
# El video 199 ha sido procesado
# 32996_2.mp4
# El video 200 ha sido procesado
# 33001_2.mp4
# El video 201 ha sido procesado
# 33006_2.mp4
# El video 202 ha sido procesado
# 33008_1.mp4
# El video 203 ha sido procesado
# 33009_2.mp4
# El video 204 ha sido procesado
# 33010_3.mp4
# El video 205 ha sido procesado
# 33012_1.mp4
# El video 206 ha sido procesado
# 33013_3.mp4
# El video 207 ha sido procesado
# 33018_1.mp4
# El video 208 ha sido procesado
# 33020_1.mp4
# El video 209 ha sido procesado
# 33023_3.mp4
# El video 210 ha sido procesado
# 33024_2.mp4
# El video 211 ha sido procesado
# 33027_2.mp4
# El video 212 ha sido procesado
# 33028_2.mp4
# El video 213 ha sido procesado
# 33029_1.mp4
# El video 214 ha sido procesado
# 33030_1.mp4
# El video 215 ha sido procesado
# 33031_2.mp4
# El video 216 ha sido procesado
# 33032_2.mp4
# El video 217 ha sido procesado
# 33034_5.mp4
# El video 218 ha sido procesado
# 33035_4.mp4
# El video 219 ha sido procesado
# 33036_2.mp4
# El video 220 ha sido procesado
# 33041_6.mp4
# El video 221 ha sido procesado
# 33043_1.mp4
# El video 222 ha sido procesado
# 33044_11.mp4
# El video 223 ha sido procesado
# 33045_1.mp4
# El video 224 ha sido procesado
# 33047_1.mp4
# El video 225 ha sido procesado
# 33048_1.mp4
# El video 226 ha sido procesado
# 33051_1.mp4
# El video 227 ha sido procesado
# 33052_1.mp4
# El video 228 ha sido procesado
# 33053_1.mp4
# El video 229 ha sido procesado
# 33056_2.mp4
# El video 230 ha sido procesado
# 33058_3.mp4
# El video 231 ha sido procesado
# 33059_1.mp4
# El video 232 ha sido procesado
# 33060_4.mp4
# El video 233 ha sido procesado
# 33061_1.mp4
# El video 234 ha sido procesado
# 33062_3.mp4
# El video 235 ha sido procesado
# 33063_6.mp4
# El video 236 ha sido procesado
# 33067_4.mp4
# El video 237 ha sido procesado
# 33068_5.mp4
# El video 238 ha sido procesado
# 33069_2.mp4
# El video 239 ha sido procesado
# 33071_1.mp4
# El video 240 ha sido procesado
# 33072_1.mp4
# El video 241 ha sido procesado
# 33073_2.mp4
# El video 242 ha sido procesado
# 33077_3.mp4
# El video 243 ha sido procesado
# 33078_1.mp4
# El video 244 ha sido procesado
# 33079_1.mp4
# El video 245 ha sido procesado
# 33080_2.mp4
# El video 246 ha sido procesado
# 33082_1.mp4
# El video 247 ha sido procesado
# 33085_1.mp4
# El video 248 ha sido procesado
# 33088_1.mp4
# El video 249 ha sido procesado
# 33090_7.mp4
# El video 250 ha sido procesado
# 33091_1.mp4
# El video 251 ha sido procesado
# 33094_1.mp4
# El video 252 ha sido procesado
# 33096_3.mp4
# El video 253 ha sido procesado
# 33099_2.mp4
# El video 254 ha sido procesado
# 33100_1.mp4
# El video 255 ha sido procesado
# 33101_4.mp4
# El video 256 ha sido procesado
# 33102_2.mp4
# El video 257 ha sido procesado
# 33103_2.mp4
# El video 258 ha sido procesado
# 33104_4.mp4
# El video 259 ha sido procesado
# 33105_3.mp4
# El video 260 ha sido procesado
# 33108_3.mp4
# El video 261 ha sido procesado
# 33109_5.mp4
# El video 262 ha sido procesado
# 33110_1.mp4
# El video 263 ha sido procesado
# 33111_1.mp4
# El video 264 ha sido procesado
# 33112_4.mp4
# El video 265 ha sido procesado
# 33113_1.mp4
# El video 266 ha sido procesado
# 33115_2.mp4
# El video 267 ha sido procesado
# 33117_1.mp4
# El video 268 ha sido procesado
# 33120_3.mp4
# El video 269 ha sido procesado
# 33122_1.mp4
# El video 270 ha sido procesado
# 33123_1.mp4
# El video 271 ha sido procesado
# 33124_2.mp4
# El video 272 ha sido procesado
# 33127_2.mp4
# El video 273 ha sido procesado
# 33132_2.mp4
# El video 274 ha sido procesado
# 33133_3.mp4
# El video 275 ha sido procesado
# 33134_1.mp4
# El video 276 ha sido procesado
# 33135_4.mp4
# El video 277 ha sido procesado
# 33136_5.mp4
# El video 278 ha sido procesado
# 33139_2.mp4
# El video 279 ha sido procesado
# 33141_1.mp4
# El video 280 ha sido procesado
# 33143_2.mp4
# El video 281 ha sido procesado
# 33144_2.mp4
# El video 282 ha sido procesado
# 33145_1.mp4
# El video 283 ha sido procesado
# 33146_1.mp4
# El video 284 ha sido procesado
# 33148_1.mp4
# El video 285 ha sido procesado
# 33149_2.mp4
# El video 286 ha sido procesado
# 33151_1.mp4
# El video 287 ha sido procesado
# 33152_6.mp4
# El video 288 ha sido procesado
# 33153_4.mp4
# El video 289 ha sido procesado
# 33154_1.mp4
# El video 290 ha sido procesado
# 33156_3.mp4
# El video 291 ha sido procesado
# 33157_2.mp4
# El video 292 ha sido procesado
# 33158_1.mp4
# El video 293 ha sido procesado
# 33159_5.mp4
# El video 294 ha sido procesado
# 33162_2.mp4
# El video 295 ha sido procesado
# 33164_1.mp4
# El video 296 ha sido procesado
# 33166_1.mp4
# El video 297 ha sido procesado
# 33168_3.mp4
# El video 298 ha sido procesado
# 33169_4.mp4
# El video 299 ha sido procesado
# 33170_1.mp4
# El video 300 ha sido procesado
# 33171_1.mp4
# El video 301 ha sido procesado
# 33172_4.mp4
# El video 302 ha sido procesado
# 33173_1.mp4
# El video 303 ha sido procesado
# 33175_6.mp4
# El video 304 ha sido procesado
# 33176_3.mp4
# El video 305 ha sido procesado
# 33177_2.mp4
# El video 306 ha sido procesado
# 33178_1.mp4
# El video 307 ha sido procesado
# 33179_1.mp4
# El video 308 ha sido procesado
# 33180_3.mp4
# El video 309 ha sido procesado
# 33182_1.mp4
# El video 310 ha sido procesado
# 33184_2.mp4
# El video 311 ha sido procesado
# 33185_4.mp4
# El video 312 ha sido procesado
# 33189_2.mp4
# El video 313 ha sido procesado
# 33191_2.mp4
# El video 314 ha sido procesado
# 33192_9.mp4
# El video 315 ha sido procesado
# 33194_1.mp4
# El video 316 ha sido procesado
# 33196_1.mp4
# El video 317 ha sido procesado
# 33197_4.mp4
# El video 318 ha sido procesado
# 33199_2.mp4
# El video 319 ha sido procesado
# 33202_2.mp4
# El video 320 ha sido procesado
# 33203_1.mp4
# El video 321 ha sido procesado
# 33205_1.mp4
# El video 322 ha sido procesado
# 33206_1.mp4
# El video 323 ha sido procesado
# 33207_1.mp4
# El video 324 ha sido procesado
# 33212_1.mp4
# El video 325 ha sido procesado
# 33216_2.mp4
# El video 326 ha sido procesado
# 33217_2.mp4
# El video 327 ha sido procesado
# 33218_2.mp4
# El video 328 ha sido procesado
# 33219_1.mp4
# El video 329 ha sido procesado
# 33222_1.mp4
# El video 330 ha sido procesado
# 33223_1.mp4
# El video 331 ha sido procesado
# 33225_1.mp4
# El video 332 ha sido procesado
# 33226_2.mp4
# El video 333 ha sido procesado
# 33229_2.mp4
# El video 334 ha sido procesado
# 33230_2.mp4
# El video 335 ha sido procesado
# 33233_1.mp4
# El video 336 ha sido procesado
# 33234_1.mp4
# El video 337 ha sido procesado
# 33235_2.mp4
# El video 338 ha sido procesado
# 33236_3.mp4
# El video 339 ha sido procesado
# 33238_3.mp4
# El video 340 ha sido procesado
# 33239_3.mp4
# El video 341 ha sido procesado
# 33240_5.mp4
# El video 342 ha sido procesado
# 33241_4.mp4
# El video 343 ha sido procesado
# 33243_7.mp4
# El video 344 ha sido procesado
# 33246_4.mp4
# El video 345 ha sido procesado
# 33248_3.mp4
# El video 346 ha sido procesado
# 33249_1.mp4
# El video 347 ha sido procesado
# 33250_2.mp4
# El video 348 ha sido procesado
# 33252_1.mp4
# El video 349 ha sido procesado
# 33253_2.mp4
# El video 350 ha sido procesado
# 33254_1.mp4
# El video 351 ha sido procesado
# 33255_1.mp4
# El video 352 ha sido procesado
# 33256_3.mp4
# El video 353 ha sido procesado
# 33257_6.mp4
# El video 354 ha sido procesado
# 33258_2.mp4
# El video 355 ha sido procesado
# 33261_5.mp4
# El video 356 ha sido procesado
# 33262_3.mp4
# El video 357 ha sido procesado
# 33263_5.mp4
# El video 358 ha sido procesado
# 33267_6.mp4
# El video 359 ha sido procesado
# 33268_7.mp4
# El video 360 ha sido procesado
# 33270_3.mp4
# El video 361 ha sido procesado
# 33271_4.mp4
# El video 362 ha sido procesado
# 33273_1.mp4
# El video 363 ha sido procesado
# 33274_2.mp4
# El video 364 ha sido procesado
# 33276_2.mp4
# El video 365 ha sido procesado
# 33277_10.mp4
# El video 366 ha sido procesado
# 33279_1.mp4
# El video 367 ha sido procesado
# 33284_1.mp4
# El video 368 ha sido procesado
# 33285_4.mp4
# El video 369 ha sido procesado
# 33287_1.mp4
# El video 370 ha sido procesado
# 33289_4.mp4
# El video 371 ha sido procesado
# 33290_1.mp4
# El video 372 ha sido procesado
# 33292_12.mp4
# El video 373 ha sido procesado
# 33294_2.mp4
# El video 374 ha sido procesado
# 33297_2.mp4
# El video 375 ha sido procesado
# 33298_1.mp4
# El video 376 ha sido procesado
# 33300_1.mp4
# El video 377 ha sido procesado
# 33301_1.mp4
# El video 378 ha sido procesado
# 33303_1.mp4
# El video 379 ha sido procesado
# 33305_8.mp4
# El video 380 ha sido procesado
# 33317_1.mp4
# El video 381 ha sido procesado
# 33318_2.mp4
# El video 382 ha sido procesado
# 33319_1.mp4
# El video 383 ha sido procesado
# 33321_4.mp4
# El video 384 ha sido procesado
# 33322_3.mp4
# El video 385 ha sido procesado
# 33323_4.mp4
# El video 386 ha sido procesado
# 33326_2.mp4
# El video 387 ha sido procesado
# 33327_2.mp4
# El video 388 ha sido procesado
# 33328_1.mp4
# El video 389 ha sido procesado
# 33329_5.mp4
# El video 390 ha sido procesado
# 33330_3.mp4
# El video 391 ha sido procesado
# 33331_4.mp4
# El video 392 ha sido procesado
# 33332_1.mp4
# El video 393 ha sido procesado
# 33334_2.mp4
# El video 394 ha sido procesado
# 33335_1.mp4
# El video 395 ha sido procesado
# 33337_3.mp4
# El video 396 ha sido procesado
# 33338_2.mp4
# El video 397 ha sido procesado
# 33339_1.mp4
# El video 398 ha sido procesado
# 33340_1.mp4
# El video 399 ha sido procesado
# 33343_1.mp4
# El video 400 ha sido procesado
# 33345_1.mp4
# El video 401 ha sido procesado
# 33347_4.mp4
# El video 402 ha sido procesado
# 33348_2.mp4
# El video 403 ha sido procesado
# 33351_1.mp4
# El video 404 ha sido procesado
# 33354_4.mp4
# El video 405 ha sido procesado
# 33356_1.mp4
# El video 406 ha sido procesado
# 33357_2.mp4
# El video 407 ha sido procesado
# 33360_1.mp4
# El video 408 ha sido procesado
# 33364_2.mp4
# El video 409 ha sido procesado
# 33367_1.mp4
# El video 410 ha sido procesado
# 33368_1.mp4
# El video 411 ha sido procesado
# 33369_1.mp4
# El video 412 ha sido procesado
# 33370_1.mp4
# El video 413 ha sido procesado
# 33371_1.mp4
# El video 414 ha sido procesado
# 33372_3.mp4
# El video 415 ha sido procesado
# 33373_5.mp4
# El video 416 ha sido procesado
# 33374_2.mp4
# El video 417 ha sido procesado
# 33375_5.mp4
# El video 418 ha sido procesado
# 33377_1.mp4
# El video 419 ha sido procesado
# 33379_1.mp4
# El video 420 ha sido procesado
# 33383_2.mp4
# El video 421 ha sido procesado
# 33384_1.mp4
# El video 422 ha sido procesado
# 33387_1.mp4
# El video 423 ha sido procesado
# 33388_4.mp4
# El video 424 ha sido procesado
# 33391_1.mp4
# El video 425 ha sido procesado
# 33393_1.mp4
# El video 426 ha sido procesado
# 33394_4.mp4
# El video 427 ha sido procesado
# 33406_8.mp4
# El video 428 ha sido procesado
# 33407_2.mp4
# El video 429 ha sido procesado
# 33409_2.mp4
# El video 430 ha sido procesado
# 33410_1.mp4
# El video 431 ha sido procesado
# 33412_2.mp4
# El video 432 ha sido procesado
# 33414_2.mp4
# El video 433 ha sido procesado
# 33416_1.mp4
# El video 434 ha sido procesado
# 33417_1.mp4
# El video 435 ha sido procesado
# 33419_4.mp4
# El video 436 ha sido procesado
# 33420_1.mp4
# El video 437 ha sido procesado
# 33425_1.mp4
# El video 438 ha sido procesado
# 33427_1.mp4
# El video 439 ha sido procesado
# 33428_2.mp4
# El video 440 ha sido procesado
# 33429_1.mp4
# El video 441 ha sido procesado
# 33430_2.mp4
# El video 442 ha sido procesado
# 33432_2.mp4
# El video 443 ha sido procesado
# 33433_2.mp4
# El video 444 ha sido procesado
# 33434_1.mp4
# El video 445 ha sido procesado
# 33435_3.mp4
# El video 446 ha sido procesado
# 33440_2.mp4
# El video 447 ha sido procesado
# 33442_3.mp4
# El video 448 ha sido procesado
# 33444_1.mp4
# El video 449 ha sido procesado
# 33447_3.mp4
# El video 450 ha sido procesado
# 33449_2.mp4
# El video 451 ha sido procesado
# 33452_1.mp4
# El video 452 ha sido procesado
# 33454_1.mp4
# El video 453 ha sido procesado
# 33456_2.mp4
# El video 454 ha sido procesado
# 33458_4.mp4
# El video 455 ha sido procesado
# 33461_2.mp4
# El video 456 ha sido procesado
# 33464_7.mp4
# El video 457 ha sido procesado
# 33466_5.mp4
# El video 458 ha sido procesado
# 33467_1.mp4
# El video 459 ha sido procesado
# 33468_2.mp4
# El video 460 ha sido procesado
# 33469_1.mp4
# El video 461 ha sido procesado
# 33470_2.mp4
# El video 462 ha sido procesado
# 33471_3.mp4
# El video 463 ha sido procesado
# 33473_6.mp4
# El video 464 ha sido procesado
# 33475_1.mp4
# El video 465 ha sido procesado
# 33478_1.mp4
# El video 466 ha sido procesado
# 33482_3.mp4
# El video 467 ha sido procesado
# 33483_2.mp4
# El video 468 ha sido procesado
# 33485_2.mp4
# El video 469 ha sido procesado
# 33486_1.mp4
# El video 470 ha sido procesado
# 33487_1.mp4
# El video 471 ha sido procesado
# 33491_1.mp4
# El video 472 ha sido procesado
# 33493_1.mp4
# El video 473 ha sido procesado
# 33495_1.mp4
# El video 474 ha sido procesado
# 33497_1.mp4
# El video 475 ha sido procesado
# 33499_1.mp4
# El video 476 ha sido procesado
# 33500_3.mp4
# El video 477 ha sido procesado
# 33501_1.mp4
# El video 478 ha sido procesado
# 33503_2.mp4
# El video 479 ha sido procesado
# 33504_1.mp4
# El video 480 ha sido procesado
# 33505_1.mp4
# El video 481 ha sido procesado
# 33508_1.mp4
# El video 482 ha sido procesado
# 33509_1.mp4
# El video 483 ha sido procesado
# 33510_1.mp4
# El video 484 ha sido procesado
# 33511_1.mp4
# El video 485 ha sido procesado
# 33512_8.mp4
# El video 486 ha sido procesado
# 33513_1.mp4
# El video 487 ha sido procesado
# 33515_5.mp4
# El video 488 ha sido procesado
# 33516_1.mp4
# El video 489 ha sido procesado
# 33521_3.mp4
# El video 490 ha sido procesado
# 33523_1.mp4
# El video 491 ha sido procesado
# 33525_1.mp4
# El video 492 ha sido procesado
# 33527_2.mp4
# El video 493 ha sido procesado
# 33528_3.mp4
# El video 494 ha sido procesado
# 33529_4.mp4
# El video 495 ha sido procesado
# 33530_1.mp4
# El video 496 ha sido procesado
# 33532_1.mp4
# El video 497 ha sido procesado
# 33533_2.mp4
# El video 498 ha sido procesado
# 33534_1.mp4
# El video 499 ha sido procesado
# 33535_1.mp4
# El video 500 ha sido procesado
# 33540_2.mp4
# El video 501 ha sido procesado
# 33542_1.mp4
# El video 502 ha sido procesado
# 33544_3.mp4
# El video 503 ha sido procesado
# 33546_3.mp4
# El video 504 ha sido procesado
# 33547_1.mp4
# El video 505 ha sido procesado
# 33551_5.mp4
# El video 506 ha sido procesado
# 33552_4.mp4
# El video 507 ha sido procesado
# 33554_3.mp4
# El video 508 ha sido procesado
# 33555_5.mp4
# El video 509 ha sido procesado
# 33558_9.mp4
# El video 510 ha sido procesado
# 33561_3.mp4
# El video 511 ha sido procesado
# 33564_9.mp4
# El video 512 ha sido procesado
# 33565_1.mp4
# El video 513 ha sido procesado
# 33566_1.mp4
# El video 514 ha sido procesado
# 33568_5.mp4
# El video 515 ha sido procesado
# 33569_1.mp4
# El video 516 ha sido procesado
# 33571_1.mp4
# El video 517 ha sido procesado
# 33572_1.mp4
# El video 518 ha sido procesado
# 33573_1.mp4
# El video 519 ha sido procesado
# 33574_3.mp4
# El video 520 ha sido procesado
# 33576_2.mp4
# El video 521 ha sido procesado
# 33577_1.mp4
# El video 522 ha sido procesado
# 33578_1.mp4
# El video 523 ha sido procesado
# 33579_4.mp4
# El video 524 ha sido procesado
# 33580_1.mp4
# El video 525 ha sido procesado
# 33582_3.mp4
# El video 526 ha sido procesado
# 33584_1.mp4
# El video 527 ha sido procesado
# 33585_1.mp4
# El video 528 ha sido procesado
# 33587_1.mp4
# El video 529 ha sido procesado
# 33588_3.mp4
# El video 530 ha sido procesado
# 33589_1.mp4
# El video 531 ha sido procesado
# 33590_5.mp4
# El video 532 ha sido procesado
# 33591_1.mp4
# El video 533 ha sido procesado
# 33594_1.mp4
# El video 534 ha sido procesado
# 33596_1.mp4
# El video 535 ha sido procesado
# 33598_1.mp4
# El video 536 ha sido procesado
# 33599_4.mp4
# El video 537 ha sido procesado
# 33600_1.mp4
# El video 538 ha sido procesado
# 33601_2.mp4
# El video 539 ha sido procesado
# 33603_1.mp4
# El video 540 ha sido procesado
# 33605_3.mp4
# El video 541 ha sido procesado
# 33606_2.mp4
# El video 542 ha sido procesado
# 33608_4.mp4
# El video 543 ha sido procesado
# 33611_1.mp4
# El video 544 ha sido procesado
# 33612_1.mp4
# El video 545 ha sido procesado
# 33613_1.mp4
# El video 546 ha sido procesado
# 33616_6.mp4
# El video 547 ha sido procesado
# 33618_1.mp4
# El video 548 ha sido procesado
# 33619_1.mp4
# El video 549 ha sido procesado
# 33620_4.mp4
# El video 550 ha sido procesado
# 33624_1.mp4
# El video 551 ha sido procesado
# 33626_1.mp4
# El video 552 ha sido procesado
# 33628_4.mp4
# El video 553 ha sido procesado
# 33629_2.mp4
# El video 554 ha sido procesado
# 33630_2.mp4
# El video 555 ha sido procesado
# 33631_3.mp4
# El video 556 ha sido procesado
# 33632_1.mp4
# El video 557 ha sido procesado
# 33634_10.mp4
# El video 558 ha sido procesado
# 33635_1.mp4
# El video 559 ha sido procesado
# 33636_2.mp4
# El video 560 ha sido procesado
# 33637_1.mp4
# El video 561 ha sido procesado
# 33638_2.mp4
# El video 562 ha sido procesado
# 33639_1.mp4
# El video 563 ha sido procesado
# 33640_1.mp4
# El video 564 ha sido procesado
# 33641_3.mp4
# El video 565 ha sido procesado
# 33642_1.mp4
# El video 566 ha sido procesado
# 33643_1.mp4
# El video 567 ha sido procesado
# 33645_2.mp4
# El video 568 ha sido procesado
# 33647_8.mp4
# El video 569 ha sido procesado
# 33648_1.mp4
# El video 570 ha sido procesado
# 33651_1.mp4
# El video 571 ha sido procesado
# 33652_1.mp4
# El video 572 ha sido procesado
# 33653_1.mp4
# El video 573 ha sido procesado
# 33654_3.mp4
# El video 574 ha sido procesado
# 33658_1.mp4
# El video 575 ha sido procesado
# 33659_3.mp4
# El video 576 ha sido procesado
# 33660_8.mp4
# El video 577 ha sido procesado
# 33662_4.mp4
# El video 578 ha sido procesado
# 33663_3.mp4
# El video 579 ha sido procesado
# 33665_1.mp4
# El video 580 ha sido procesado
# 33666_7.mp4
# El video 581 ha sido procesado
# 33667_1.mp4
# El video 582 ha sido procesado
# 33669_3.mp4
# El video 583 ha sido procesado
# 33670_3.mp4
# El video 584 ha sido procesado
# 33671_1.mp4
# El video 585 ha sido procesado
# 33673_1.mp4
# El video 586 ha sido procesado
# 33674_2.mp4
# El video 587 ha sido procesado
# 33675_1.mp4
# El video 588 ha sido procesado
# 33676_1.mp4
# El video 589 ha sido procesado
# 33682_3.mp4
# El video 590 ha sido procesado
# 33685_1.mp4
# El video 591 ha sido procesado
# 33687_1.mp4
# El video 592 ha sido procesado
# 33691_4.mp4
# El video 593 ha sido procesado
# 33692_3.mp4
# El video 594 ha sido procesado
# 33693_1.mp4
# El video 595 ha sido procesado
# 33696_1.mp4
# El video 596 ha sido procesado
# 33697_4.mp4
# El video 597 ha sido procesado
# 33699_9.mp4
# El video 598 ha sido procesado
# 33700_5.mp4
# El video 599 ha sido procesado
# 33701_2.mp4
# El video 600 ha sido procesado
# 33702_5.mp4
# El video 601 ha sido procesado
# 33703_1.mp4
# El video 602 ha sido procesado
# 33704_2.mp4
# El video 603 ha sido procesado
# 33706_1.mp4
# El video 604 ha sido procesado
# 33709_6.mp4
# El video 605 ha sido procesado
# 33710_5.mp4
# El video 606 ha sido procesado
# 33711_1.mp4
# El video 607 ha sido procesado
# 33712_4.mp4
# El video 608 ha sido procesado
# 33713_1.mp4
# El video 609 ha sido procesado
# 33715_1.mp4
# El video 610 ha sido procesado
# 33716_1.mp4
# El video 611 ha sido procesado
# 33718_1.mp4
# El video 612 ha sido procesado
# 33719_3.mp4
# El video 613 ha sido procesado
# 33723_1.mp4
# El video 614 ha sido procesado
# 33724_1.mp4
# El video 615 ha sido procesado
# 33725_2.mp4
# El video 616 ha sido procesado
# 33726_5.mp4
# El video 617 ha sido procesado
# 33727_1.mp4
# El video 618 ha sido procesado
# 33729_4.mp4
# El video 619 ha sido procesado
# 33732_1.mp4
# El video 620 ha sido procesado
# 33733_1.mp4
# El video 621 ha sido procesado
# 33735_8.mp4
# El video 622 ha sido procesado
# 33736_1.mp4
# El video 623 ha sido procesado
# 33741_1.mp4
# El video 624 ha sido procesado
# 33742_1.mp4
# El video 625 ha sido procesado
# 33743_1.mp4
# El video 626 ha sido procesado
# 33744_4.mp4
# El video 627 ha sido procesado
# 33747_2.mp4
# El video 628 ha sido procesado
# 33748_10.mp4
# El video 629 ha sido procesado
# 33751_1.mp4
# El video 630 ha sido procesado
# 33752_3.mp4
# El video 631 ha sido procesado
# 33756_2.mp4
# El video 632 ha sido procesado
# 33757_4.mp4
# El video 633 ha sido procesado
# 33758_1.mp4
# El video 634 ha sido procesado
# 33761_2.mp4
# El video 635 ha sido procesado
# 33762_2.mp4
# El video 636 ha sido procesado
# 33764_1.mp4
# El video 637 ha sido procesado
# 33765_1.mp4
# El video 638 ha sido procesado
# 33766_1.mp4
# El video 639 ha sido procesado
# 33767_1.mp4
# El video 640 ha sido procesado
# 33768_1.mp4
# El video 641 ha sido procesado
# 33769_3.mp4
# El video 642 ha sido procesado
# 33771_3.mp4
# El video 643 ha sido procesado
# 33773_3.mp4
# El video 644 ha sido procesado
# 33774_4.mp4
# El video 645 ha sido procesado
# 33775_3.mp4
# El video 646 ha sido procesado
# 33777_8.mp4
# El video 647 ha sido procesado
# 33780_1.mp4
# El video 648 ha sido procesado
# 33781_1.mp4
# El video 649 ha sido procesado
# 33782_6.mp4
# El video 650 ha sido procesado
# 33786_6.mp4
# El video 651 ha sido procesado
# 33787_1.mp4
# El video 652 ha sido procesado
# 33789_4.mp4
# El video 653 ha sido procesado
# 33791_3.mp4
# El video 654 ha sido procesado
# 33793_6.mp4
# El video 655 ha sido procesado
# 33794_4.mp4
# El video 656 ha sido procesado
# 33797_5.mp4
# El video 657 ha sido procesado
# 33801_4.mp4
# El video 658 ha sido procesado
# 33802_1.mp4
# El video 659 ha sido procesado
# 33803_2.mp4
# El video 660 ha sido procesado
# 33804_3.mp4
# El video 661 ha sido procesado
# 33805_1.mp4
# El video 662 ha sido procesado
# 33807_1.mp4
# El video 663 ha sido procesado
# 33809_1.mp4
# El video 664 ha sido procesado
# 33811_1.mp4
# El video 665 ha sido procesado
# 33815_1.mp4
# El video 666 ha sido procesado
# 33816_1.mp4
# El video 667 ha sido procesado
# 33819_1.mp4
# El video 668 ha sido procesado
# 33820_3.mp4
# El video 669 ha sido procesado
# 33821_1.mp4
# El video 670 ha sido procesado
# 33822_1.mp4
# El video 671 ha sido procesado
# 33823_1.mp4
# El video 672 ha sido procesado
# 33824_4.mp4
# El video 673 ha sido procesado
# 33827_1.mp4
# El video 674 ha sido procesado
# 33828_1.mp4
# El video 675 ha sido procesado
# 33830_5.mp4
# El video 676 ha sido procesado
# 33831_7.mp4
# El video 677 ha sido procesado
# 33834_1.mp4
# El video 678 ha sido procesado
# 33837_1.mp4
# El video 679 ha sido procesado
# 33838_3.mp4
# El video 680 ha sido procesado
# 33839_1.mp4
# El video 681 ha sido procesado
# 33840_4.mp4
# El video 682 ha sido procesado
# 33843_1.mp4
# El video 683 ha sido procesado
# 33844_2.mp4
# El video 684 ha sido procesado
# 33845_1.mp4
# El video 685 ha sido procesado
# 33846_1.mp4
# El video 686 ha sido procesado
# 33847_2.mp4
# El video 687 ha sido procesado
# 33849_3.mp4
# El video 688 ha sido procesado
# 33850_1.mp4
# El video 689 ha sido procesado
# 33856_5.mp4
# El video 690 ha sido procesado
# 33860_3.mp4
# El video 691 ha sido procesado
# 33861_4.mp4
# El video 692 ha sido procesado
# 33862_3.mp4
# El video 693 ha sido procesado
# 33863_1.mp4
# El video 694 ha sido procesado
# 33864_6.mp4
# El video 695 ha sido procesado
# 33865_1.mp4
# El video 696 ha sido procesado
# 33866_1.mp4
# El video 697 ha sido procesado
# 33867_5.mp4
# El video 698 ha sido procesado
# 33868_1.mp4
# El video 699 ha sido procesado
# 33869_1.mp4
# El video 700 ha sido procesado
# 33870_1.mp4
# El video 701 ha sido procesado
# 33871_3.mp4
# El video 702 ha sido procesado
# 33874_5.mp4
# El video 703 ha sido procesado
# 33875_1.mp4
# El video 704 ha sido procesado
# 33876_9.mp4
# El video 705 ha sido procesado
# 33877_2.mp4
# El video 706 ha sido procesado
# 33878_1.mp4
# El video 707 ha sido procesado
# 33879_7.mp4
# El video 708 ha sido procesado
# 33880_1.mp4
# El video 709 ha sido procesado
# 33882_2.mp4
# El video 710 ha sido procesado
# 33883_3.mp4
# El video 711 ha sido procesado
# 33884_1.mp4
# El video 712 ha sido procesado
# 33886_4.mp4
# El video 713 ha sido procesado
# 33888_1.mp4
# El video 714 ha sido procesado
# 33890_2.mp4
# El video 715 ha sido procesado
# 33891_1.mp4
# El video 716 ha sido procesado
# 33892_1.mp4
# El video 717 ha sido procesado
# 33893_1.mp4
# El video 718 ha sido procesado
# 33897_1.mp4
# El video 719 ha sido procesado
# 33898_1.mp4
# El video 720 ha sido procesado
# 33903_1.mp4
# El video 721 ha sido procesado
# 33905_1.mp4
# El video 722 ha sido procesado
# 36015_1.mp4
# El video 723 ha sido procesado
# 36016_1.mp4
# El video 724 ha sido procesado
# 36018_1.mp4
# El video 725 ha sido procesado
# 36021_1.mp4
# El video 726 ha sido procesado
# 36023_6.mp4
# El video 727 ha sido procesado
# 36024_1.mp4
# El video 728 ha sido procesado
# 36025_1.mp4
# El video 729 ha sido procesado
# 36026_1.mp4
# El video 730 ha sido procesado
# 36027_1.mp4
# El video 731 ha sido procesado
# 36028_1.mp4
# El video 732 ha sido procesado
# 36029_1.mp4
# El video 733 ha sido procesado
# 36031_1.mp4
# El video 734 ha sido procesado
# 36035_2.mp4
# El video 735 ha sido procesado
# 36036_1.mp4
# El video 736 ha sido procesado
# 36037_2.mp4
# El video 737 ha sido procesado
# 36040_3.mp4
# El video 738 ha sido procesado
# 36041_6.mp4
# El video 739 ha sido procesado
# 36042_1.mp4
# El video 740 ha sido procesado
# 36043_3.mp4
# El video 741 ha sido procesado
# 36044_8.mp4
# El video 742 ha sido procesado
# 36045_2.mp4
# El video 743 ha sido procesado
# 36046_4.mp4
# El video 744 ha sido procesado
# 36047_2.mp4
# El video 745 ha sido procesado
# 36052_5.mp4
# El video 746 ha sido procesado
# 36053_1.mp4
# El video 747 ha sido procesado
# 36054_13.mp4
# El video 748 ha sido procesado
# 36055_4.mp4
# El video 749 ha sido procesado
# 36057_1.mp4
# El video 750 ha sido procesado
# 36058_3.mp4
# El video 751 ha sido procesado
# 36059_2.mp4
# El video 752 ha sido procesado
# 36065_3.mp4
# El video 753 ha sido procesado
# 36068_2.mp4
# El video 754 ha sido procesado
# 36069_5.mp4
# El video 755 ha sido procesado
# 36071_2.mp4
# El video 756 ha sido procesado
# 36073_1.mp4
# El video 757 ha sido procesado
# 36074_1.mp4
# El video 758 ha sido procesado
# 36077_1.mp4
# El video 759 ha sido procesado
# 36080_4.mp4
# El video 760 ha sido procesado
# 36081_3.mp4
# El video 761 ha sido procesado
# 36082_2.mp4
# El video 762 ha sido procesado
# 36083_1.mp4
# El video 763 ha sido procesado
# 36084_1.mp4
# El video 764 ha sido procesado
# 36085_1.mp4
# El video 765 ha sido procesado
# 36088_1.mp4
# El video 766 ha sido procesado
# 36090_1.mp4
# El video 767 ha sido procesado
# 36091_2.mp4
# El video 768 ha sido procesado
# 36092_3.mp4
# El video 769 ha sido procesado
# 36093_1.mp4
# El video 770 ha sido procesado
# 36096_1.mp4
# El video 771 ha sido procesado
# 36097_1.mp4
# El video 772 ha sido procesado
# 36098_2.mp4
# El video 773 ha sido procesado
# 36099_6.mp4
# El video 774 ha sido procesado
# 36100_1.mp4
# El video 775 ha sido procesado
# 36101_2.mp4
# El video 776 ha sido procesado
# 36108_6.mp4
# El video 777 ha sido procesado
# 36109_1.mp4
# El video 778 ha sido procesado
# 36110_8.mp4
# El video 779 ha sido procesado
# 36112_1.mp4
# El video 780 ha sido procesado
# 36113_1.mp4
# El video 781 ha sido procesado
# 36114_1.mp4
# El video 782 ha sido procesado
# 36118_1.mp4
# El video 783 ha sido procesado
# 36119_1.mp4
# El video 784 ha sido procesado
# 36120_3.mp4
# El video 785 ha sido procesado
# 36122_2.mp4
# El video 786 ha sido procesado
# 36124_1.mp4
# El video 787 ha sido procesado
# 36126_1.mp4
# El video 788 ha sido procesado
# 36128_4.mp4
# El video 789 ha sido procesado
# 36129_2.mp4
# El video 790 ha sido procesado
# 36131_1.mp4
# El video 791 ha sido procesado
# 36132_1.mp4
# El video 792 ha sido procesado
# 36133_2.mp4
# El video 793 ha sido procesado
# 36138_3.mp4
# El video 794 ha sido procesado
# 36139_2.mp4
# El video 795 ha sido procesado
# 36140_3.mp4
# El video 796 ha sido procesado
# 36141_2.mp4
# El video 797 ha sido procesado
# 36143_1.mp4
# El video 798 ha sido procesado
# 36145_1.mp4
# El video 799 ha sido procesado
# 36146_1.mp4
# El video 800 ha sido procesado
# 36150_1.mp4
# El video 801 ha sido procesado
# 36151_3.mp4
# El video 802 ha sido procesado
# 36153_2.mp4
# El video 803 ha sido procesado
# 36154_3.mp4
# El video 804 ha sido procesado
# 36155_3.mp4
# El video 805 ha sido procesado
# 36157_1.mp4
# El video 806 ha sido procesado
# 36158_2.mp4
# El video 807 ha sido procesado
# 36163_1.mp4
# El video 808 ha sido procesado
# 36165_1.mp4
# El video 809 ha sido procesado
# 36166_1.mp4
# El video 810 ha sido procesado
# 36170_1.mp4
# El video 811 ha sido procesado
# 36173_1.mp4
# El video 812 ha sido procesado
# 36176_1.mp4
# El video 813 ha sido procesado
# 36179_1.mp4
# El video 814 ha sido procesado
# 36180_1.mp4
# El video 815 ha sido procesado
# 36181_3.mp4
# El video 816 ha sido procesado
# 36182_3.mp4
# El video 817 ha sido procesado
# 36184_8.mp4
# El video 818 ha sido procesado
# 36185_1.mp4
# El video 819 ha sido procesado
# 36186_3.mp4
# El video 820 ha sido procesado
# 36188_3.mp4
# El video 821 ha sido procesado
# 36189_1.mp4
# El video 822 ha sido procesado
# 36190_2.mp4
# El video 823 ha sido procesado
# 36193_1.mp4
# El video 824 ha sido procesado
# 36195_1.mp4
# El video 825 ha sido procesado
# 36197_1.mp4
# El video 826 ha sido procesado
# 36198_2.mp4
# El video 827 ha sido procesado
# 36200_7.mp4
# El video 828 ha sido procesado
# 36201_11.mp4
# El video 829 ha sido procesado
# 36202_8.mp4
# El video 830 ha sido procesado
# 36205_1.mp4
# El video 831 ha sido procesado
# 36206_2.mp4
# El video 832 ha sido procesado
# 36207_2.mp4
# El video 833 ha sido procesado
# 36212_3.mp4
# El video 834 ha sido procesado
# 36215_1.mp4
# El video 835 ha sido procesado
# 36216_1.mp4
# El video 836 ha sido procesado
# 36217_2.mp4
# El video 837 ha sido procesado
# 36218_1.mp4
# El video 838 ha sido procesado
# 36219_5.mp4
# El video 839 ha sido procesado
# 36221_1.mp4
# El video 840 ha sido procesado
# 36222_1.mp4
# El video 841 ha sido procesado
# 36224_1.mp4
# El video 842 ha sido procesado
# 36225_1.mp4
# El video 843 ha sido procesado
# 36226_1.mp4
# El video 844 ha sido procesado
# 36227_8.mp4
# El video 845 ha sido procesado
# 36228_1.mp4
# El video 846 ha sido procesado
# 36229_1.mp4
# El video 847 ha sido procesado
# 36230_1.mp4
# El video 848 ha sido procesado
# 36231_2.mp4
# El video 849 ha sido procesado
# 36233_1.mp4
# El video 850 ha sido procesado
# 36236_2.mp4
# El video 851 ha sido procesado
# 36238_5.mp4
# El video 852 ha sido procesado
# 36240_1.mp4
# El video 853 ha sido procesado
# 36243_3.mp4
# El video 854 ha sido procesado
# 36245_7.mp4
# El video 855 ha sido procesado
# 36247_2.mp4
# El video 856 ha sido procesado
# 36248_1.mp4
# El video 857 ha sido procesado
# 36249_1.mp4
# El video 858 ha sido procesado
# 36250_2.mp4
# El video 859 ha sido procesado
# 36251_2.mp4
# El video 860 ha sido procesado
# 36252_1.mp4
# El video 861 ha sido procesado
# 36254_3.mp4
# El video 862 ha sido procesado
# 36255_1.mp4
# El video 863 ha sido procesado
# 36256_1.mp4
# El video 864 ha sido procesado
# 36257_1.mp4
# El video 865 ha sido procesado
# 36258_1.mp4
# El video 866 ha sido procesado
# 36260_10.mp4
# El video 867 ha sido procesado
# 36261_1.mp4
# El video 868 ha sido procesado
# 36262_2.mp4
# El video 869 ha sido procesado
# 36264_2.mp4
# El video 870 ha sido procesado
# 36267_1.mp4
# El video 871 ha sido procesado
# 36268_1.mp4
# El video 872 ha sido procesado
# 36269_1.mp4
# El video 873 ha sido procesado
# 36270_17.mp4
# El video 874 ha sido procesado
# 36271_3.mp4
# El video 875 ha sido procesado
# 36273_7.mp4
# El video 876 ha sido procesado
# 36274_1.mp4
# El video 877 ha sido procesado
# 36275_2.mp4
# El video 878 ha sido procesado
# 36276_4.mp4
# El video 879 ha sido procesado
# 36277_1.mp4
# El video 880 ha sido procesado
# 36278_1.mp4
# El video 881 ha sido procesado
# 36280_1.mp4
# El video 882 ha sido procesado
# 36281_3.mp4
# El video 883 ha sido procesado
# 36283_1.mp4
# El video 884 ha sido procesado
# 36284_1.mp4
# El video 885 ha sido procesado
# 36286_1.mp4
# El video 886 ha sido procesado
# 36288_3.mp4
# El video 887 ha sido procesado
# 36289_4.mp4
# El video 888 ha sido procesado
# 36290_1.mp4
# El video 889 ha sido procesado
# 36291_1.mp4
# El video 890 ha sido procesado
# 36292_2.mp4
# El video 891 ha sido procesado
# 36295_1.mp4
# El video 892 ha sido procesado
# 36296_2.mp4
# El video 893 ha sido procesado
# 36299_1.mp4
# El video 894 ha sido procesado
# 36301_3.mp4
# El video 895 ha sido procesado
# 36303_2.mp4
# El video 896 ha sido procesado
# 36306_1.mp4
# El video 897 ha sido procesado
# 36308_2.mp4
# El video 898 ha sido procesado
# 36309_3.mp4
# El video 899 ha sido procesado
# 36310_5.mp4
# El video 900 ha sido procesado
# 36311_1.mp4
# El video 901 ha sido procesado
# 36313_4.mp4
# El video 902 ha sido procesado
# 36316_1.mp4
# El video 903 ha sido procesado
# 36317_1.mp4
# El video 904 ha sido procesado
# 36318_5.mp4
# El video 905 ha sido procesado
# 36319_1.mp4
# El video 906 ha sido procesado
# 36320_2.mp4
# El video 907 ha sido procesado
# 36321_3.mp4
# El video 908 ha sido procesado
# 36323_1.mp4
# El video 909 ha sido procesado
# 36324_1.mp4
# El video 910 ha sido procesado
# 36325_1.mp4
# El video 911 ha sido procesado
# 36326_2.mp4
# El video 912 ha sido procesado
# 36327_1.mp4
# El video 913 ha sido procesado
# 36331_2.mp4
# El video 914 ha sido procesado
# 36332_2.mp4
# El video 915 ha sido procesado
# 36334_7.mp4
# El video 916 ha sido procesado
# 36335_7.mp4
# El video 917 ha sido procesado
# 36336_1.mp4
# El video 918 ha sido procesado
# 36338_2.mp4
# El video 919 ha sido procesado
# 36342_18.mp4
# El video 920 ha sido procesado
# 36344_4.mp4
# El video 921 ha sido procesado
# 36345_3.mp4
# El video 922 ha sido procesado
# 36347_1.mp4
# El video 923 ha sido procesado
# 36350_4.mp4
# El video 924 ha sido procesado
# 36351_11.mp4
# El video 925 ha sido procesado
# 36353_3.mp4
# El video 926 ha sido procesado
# 36354_2.mp4
# El video 927 ha sido procesado
# 36357_1.mp4
# El video 928 ha sido procesado
# 36358_1.mp4
# El video 929 ha sido procesado
# 36359_3.mp4
# El video 930 ha sido procesado
# 36360_2.mp4
# El video 931 ha sido procesado
# 36361_1.mp4
# El video 932 ha sido procesado
# 36362_6.mp4
# El video 933 ha sido procesado
# 36365_3.mp4
# El video 934 ha sido procesado
# 36371_2.mp4
# El video 935 ha sido procesado
# 36373_1.mp4
# El video 936 ha sido procesado
# 36375_1.mp4
# El video 937 ha sido procesado
# 36380_3.mp4
# El video 938 ha sido procesado
# 36382_2.mp4
# El video 939 ha sido procesado
# 36383_4.mp4
# El video 940 ha sido procesado
# 36384_2.mp4
# El video 941 ha sido procesado
# 36389_4.mp4
# El video 942 ha sido procesado
# 36392_1.mp4
# El video 943 ha sido procesado
# 36393_2.mp4
# El video 944 ha sido procesado
# 36397_2.mp4
# El video 945 ha sido procesado
# 36399_1.mp4
# El video 946 ha sido procesado
# 36402_4.mp4
# El video 947 ha sido procesado
# 36405_4.mp4
# El video 948 ha sido procesado
# 36407_1.mp4
# El video 949 ha sido procesado
# 36408_2.mp4
# El video 950 ha sido procesado
# 36409_5.mp4
# El video 951 ha sido procesado
# 36411_5.mp4
# El video 952 ha sido procesado
# 36412_5.mp4
# El video 953 ha sido procesado
# 36415_1.mp4
# El video 954 ha sido procesado
# 36417_5.mp4
# El video 955 ha sido procesado
# 36418_3.mp4
# El video 956 ha sido procesado
# 36421_1.mp4
# El video 957 ha sido procesado
# 36422_2.mp4
# El video 958 ha sido procesado
# 36423_3.mp4
# El video 959 ha sido procesado
# 36425_1.mp4
# El video 960 ha sido procesado
# 36427_3.mp4
# El video 961 ha sido procesado
# 36429_1.mp4
# El video 962 ha sido procesado
# 36430_4.mp4
# El video 963 ha sido procesado
# 36431_1.mp4
# El video 964 ha sido procesado
# 36432_5.mp4
# El video 965 ha sido procesado
# 36434_2.mp4
# El video 966 ha sido procesado
# 36435_4.mp4
# El video 967 ha sido procesado
# 36441_1.mp4
# El video 968 ha sido procesado
# 36442_3.mp4
# El video 969 ha sido procesado
# 36448_1.mp4
# El video 970 ha sido procesado
# 36449_2.mp4
# El video 971 ha sido procesado
# 36450_1.mp4
# El video 972 ha sido procesado
# 36451_5.mp4
# El video 973 ha sido procesado
# 36453_3.mp4
# El video 974 ha sido procesado
# 36456_1.mp4
# El video 975 ha sido procesado
# 36458_11.mp4
# El video 976 ha sido procesado
# 36460_3.mp4
# El video 977 ha sido procesado
# 36462_6.mp4
# El video 978 ha sido procesado
# 36464_2.mp4
# El video 979 ha sido procesado
# 36468_1.mp4
# El video 980 ha sido procesado
# 36471_2.mp4
# El video 981 ha sido procesado
# 36472_3.mp4
# El video 982 ha sido procesado
# 36473_3.mp4
# El video 983 ha sido procesado
# 36474_2.mp4
# El video 984 ha sido procesado
# 36475_5.mp4
# El video 985 ha sido procesado
# 36476_3.mp4
# El video 986 ha sido procesado
# 36477_2.mp4
# El video 987 ha sido procesado
# 36478_7.mp4
# El video 988 ha sido procesado
# 36480_5.mp4
# El video 989 ha sido procesado
# 36482_3.mp4
# El video 990 ha sido procesado
# 36487_2.mp4
# El video 991 ha sido procesado
# 36490_2.mp4
# El video 992 ha sido procesado
# 36492_5.mp4
# El video 993 ha sido procesado
# 36493_2.mp4
# El video 994 ha sido procesado
# 36494_1.mp4
# El video 995 ha sido procesado
# 36495_1.mp4
# El video 996 ha sido procesado
# 36496_3.mp4
# El video 997 ha sido procesado
# 36497_2.mp4
# El video 998 ha sido procesado
# 36499_1.mp4
# El video 999 ha sido procesado
# 36500_2.mp4
# El video 1000 ha sido procesado
# 36501_1.mp4
# El video 1001 ha sido procesado
# 36502_2.mp4
# El video 1002 ha sido procesado
# 36503_2.mp4
# El video 1003 ha sido procesado
# 36506_1.mp4
# El video 1004 ha sido procesado
# 36507_4.mp4
# El video 1005 ha sido procesado
# 36508_1.mp4
# El video 1006 ha sido procesado
# 36511_1.mp4
# El video 1007 ha sido procesado
# 36525_1.mp4
# El video 1008 ha sido procesado
# 36527_3.mp4
# El video 1009 ha sido procesado
# 36529_5.mp4
# El video 1010 ha sido procesado
# 36530_3.mp4
# El video 1011 ha sido procesado
# 36531_2.mp4
# El video 1012 ha sido procesado
# 36532_7.mp4
# El video 1013 ha sido procesado
# 36533_5.mp4
# El video 1014 ha sido procesado
# 36534_5.mp4
# El video 1015 ha sido procesado
# 36536_4.mp4
# El video 1016 ha sido procesado
# 36537_1.mp4
# El video 1017 ha sido procesado
# 36538_4.mp4
# El video 1018 ha sido procesado
# 36539_1.mp4
# El video 1019 ha sido procesado
# 36541_2.mp4
# El video 1020 ha sido procesado
# 36544_1.mp4
# El video 1021 ha sido procesado
# 36546_2.mp4
# El video 1022 ha sido procesado
# 36547_1.mp4
# El video 1023 ha sido procesado
# 36548_3.mp4
# El video 1024 ha sido procesado
# 36550_4.mp4
# El video 1025 ha sido procesado
# 36551_4.mp4
# El video 1026 ha sido procesado
# 36552_1.mp4
# El video 1027 ha sido procesado
# 36554_5.mp4
# El video 1028 ha sido procesado
# 36557_3.mp4
# El video 1029 ha sido procesado
# 36558_1.mp4
# El video 1030 ha sido procesado
# 36562_1.mp4
# El video 1031 ha sido procesado
# 36563_2.mp4
# El video 1032 ha sido procesado
# 36564_1.mp4
# El video 1033 ha sido procesado
# 36566_1.mp4
# El video 1034 ha sido procesado
# 36567_2.mp4
# El video 1035 ha sido procesado
# 36569_6.mp4
# El video 1036 ha sido procesado
# 36571_2.mp4
# El video 1037 ha sido procesado
# 36573_1.mp4
# El video 1038 ha sido procesado
# 36574_3.mp4
# El video 1039 ha sido procesado
# 36576_1.mp4
# El video 1040 ha sido procesado
# 36577_1.mp4
# El video 1041 ha sido procesado
# 36579_1.mp4
# El video 1042 ha sido procesado
# 36581_1.mp4
# El video 1043 ha sido procesado
# 36582_4.mp4
# El video 1044 ha sido procesado
# 36584_1.mp4
# El video 1045 ha sido procesado
# 36585_1.mp4
# El video 1046 ha sido procesado
# 36586_1.mp4
# El video 1047 ha sido procesado
# 36587_1.mp4
# El video 1048 ha sido procesado
# 36588_2.mp4
# El video 1049 ha sido procesado
# 36590_1.mp4
# El video 1050 ha sido procesado
# 36592_1.mp4
# El video 1051 ha sido procesado
# 36593_5.mp4
# El video 1052 ha sido procesado
# 36594_1.mp4
# El video 1053 ha sido procesado
# 36595_3.mp4
# El video 1054 ha sido procesado
# 36596_3.mp4
# El video 1055 ha sido procesado
# 36597_5.mp4
# El video 1056 ha sido procesado
# 36598_10.mp4
# El video 1057 ha sido procesado
# 36599_2.mp4
# El video 1058 ha sido procesado
# 36602_4.mp4
# El video 1059 ha sido procesado
# 36606_1.mp4
# El video 1060 ha sido procesado
# 36607_1.mp4
# El video 1061 ha sido procesado
# 36608_2.mp4
# El video 1062 ha sido procesado
# 36611_2.mp4
# El video 1063 ha sido procesado
# 36613_2.mp4
# El video 1064 ha sido procesado
# 36614_10.mp4
# El video 1065 ha sido procesado
# 36619_1.mp4
# El video 1066 ha sido procesado
# 36621_2.mp4
# El video 1067 ha sido procesado
# 36622_1.mp4
# El video 1068 ha sido procesado
# 36626_1.mp4
# El video 1069 ha sido procesado
# 36627_3.mp4
# El video 1070 ha sido procesado
# 36630_1.mp4
# El video 1071 ha sido procesado
# 36632_1.mp4
# El video 1072 ha sido procesado
# 36633_1.mp4
# El video 1073 ha sido procesado
# 36634_4.mp4
# El video 1074 ha sido procesado
# 36635_1.mp4
# El video 1075 ha sido procesado
# 36638_1.mp4
# El video 1076 ha sido procesado
# 36639_2.mp4
# El video 1077 ha sido procesado
# 36640_1.mp4
# El video 1078 ha sido procesado
# 36641_1.mp4
# El video 1079 ha sido procesado
# 36643_2.mp4
# El video 1080 ha sido procesado
# 36644_6.mp4
# El video 1081 ha sido procesado
# 36645_3.mp4
# El video 1082 ha sido procesado
# 36646_5.mp4
# El video 1083 ha sido procesado
# 36647_1.mp4
# El video 1084 ha sido procesado
# 36649_1.mp4
# El video 1085 ha sido procesado
# 36653_2.mp4
# El video 1086 ha sido procesado
# 36654_1.mp4
# El video 1087 ha sido procesado
# 36655_1.mp4
# El video 1088 ha sido procesado
# 36657_2.mp4
# El video 1089 ha sido procesado
# 36658_4.mp4
# El video 1090 ha sido procesado
# 36659_2.mp4
# El video 1091 ha sido procesado
# 36660_1.mp4
# El video 1092 ha sido procesado
# 36663_1.mp4
# El video 1093 ha sido procesado
# 36664_5.mp4
# El video 1094 ha sido procesado
# 36665_2.mp4
# El video 1095 ha sido procesado
# 36667_1.mp4
# El video 1096 ha sido procesado
# 36668_2.mp4
# El video 1097 ha sido procesado
# 36669_2.mp4
# El video 1098 ha sido procesado
# 36672_1.mp4
# El video 1099 ha sido procesado
# 36673_1.mp4
# El video 1100 ha sido procesado
# 36674_2.mp4
# El video 1101 ha sido procesado
# 36675_2.mp4
# El video 1102 ha sido procesado
# 36677_1.mp4
# El video 1103 ha sido procesado
# 36678_2.mp4
# El video 1104 ha sido procesado
# 36679_5.mp4
# El video 1105 ha sido procesado
# 36680_12.mp4
# El video 1106 ha sido procesado
# 36683_3.mp4
# El video 1107 ha sido procesado
# 36685_1.mp4
# El video 1108 ha sido procesado
# 36686_1.mp4
# El video 1109 ha sido procesado
# 36687_3.mp4
# El video 1110 ha sido procesado
# 36688_1.mp4
# El video 1111 ha sido procesado
# 36690_3.mp4
# El video 1112 ha sido procesado
# 36694_1.mp4
# El video 1113 ha sido procesado
# 36697_4.mp4
# El video 1114 ha sido procesado
# ...
# 50112_3.mp4
# El video 4607 ha sido procesado
# 50113_1.mp4
# El video 4608 ha sido procesado
# 50114_6.mp4
# El video 4609 ha sido procesado
# 50115_5.mp4
# El video 4610 ha sido procesado
# 50117_4.mp4
# El video 4611 ha sido procesado
# 50121_1.mp4
# El video 4612 ha sido procesado
# 50122_2.mp4
# El video 4613 ha sido procesado
# 50123_2.mp4
# El video 4614 ha sido procesado
# 50125_1.mp4
# El video 4615 ha sido procesado
# 50126_1.mp4
# El video 4616 ha sido procesado
# 50130_2.mp4
# El video 4617 ha sido procesado
# 50131_2.mp4
# El video 4618 ha sido procesado
# 50134_7.mp4
# El video 4619 ha sido procesado
# 50135_2.mp4
# El video 4620 ha sido procesado
# 50136_1.mp4
# El video 4621 ha sido procesado
# 50137_1.mp4
# El video 4622 ha sido procesado
# 50138_1.mp4
# El video 4623 ha sido procesado
# 50144_3.mp4
# El video 4624 ha sido procesado
# 50145_2.mp4
# El video 4625 ha sido procesado
# 50146_3.mp4
# El video 4626 ha sido procesado
# 50147_3.mp4
# El video 4627 ha sido procesado
# 50151_1.mp4
# El video 4628 ha sido procesado
# 50152_1.mp4
# El video 4629 ha sido procesado
# 50153_1.mp4
# El video 4630 ha sido procesado
# 50154_1.mp4
# El video 4631 ha sido procesado
# 50155_1.mp4
# El video 4632 ha sido procesado
# 50157_5.mp4
# El video 4633 ha sido procesado
# 50158_12.mp4
# El video 4634 ha sido procesado
# 50160_6.mp4
# El video 4635 ha sido procesado
# 50162_3.mp4
# El video 4636 ha sido procesado
# 50168_3.mp4
# El video 4637 ha sido procesado
# 50170_1.mp4
# El video 4638 ha sido procesado
# 50171_4.mp4
# El video 4639 ha sido procesado
# 50172_2.mp4
# El video 4640 ha sido procesado
# 50174_1.mp4
# El video 4641 ha sido procesado
# 50176_1.mp4
# El video 4642 ha sido procesado
# 50178_2.mp4
# El video 4643 ha sido procesado
# 50179_2.mp4
# El video 4644 ha sido procesado
# 50183_2.mp4
# El video 4645 ha sido procesado
# 50185_2.mp4
# El video 4646 ha sido procesado
# 50187_7.mp4
# El video 4647 ha sido procesado
# 50189_3.mp4
# El video 4648 ha sido procesado
# 50190_4.mp4
# El video 4649 ha sido procesado
# 50192_2.mp4
# El video 4650 ha sido procesado
# 50198_1.mp4
# El video 4651 ha sido procesado
# 50199_1.mp4
# El video 4652 ha sido procesado
# 50201_1.mp4
# El video 4653 ha sido procesado
# 50202_1.mp4
# El video 4654 ha sido procesado
# 50204_1.mp4
# El video 4655 ha sido procesado
# 50205_4.mp4
# El video 4656 ha sido procesado
# 50206_1.mp4
# El video 4657 ha sido procesado
# 50207_1.mp4
# El video 4658 ha sido procesado
# 50210_1.mp4
# El video 4659 ha sido procesado
# 50214_1.mp4
# El video 4660 ha sido procesado
# 50215_21.mp4
# El video 4661 ha sido procesado
# 50216_3.mp4
# El video 4662 ha sido procesado
# 50219_1.mp4
# El video 4663 ha sido procesado
# 50220_5.mp4
# El video 4664 ha sido procesado
# 50221_1.mp4
# El video 4665 ha sido procesado
# 50222_3.mp4
# El video 4666 ha sido procesado
# 50224_1.mp4
# El video 4667 ha sido procesado
# 50227_3.mp4
# El video 4668 ha sido procesado
# 50229_3.mp4
# El video 4669 ha sido procesado
# 50232_30.mp4
# El video 4670 ha sido procesado
# 50234_1.mp4
# El video 4671 ha sido procesado
# 50238_1.mp4
# El video 4672 ha sido procesado
# 50239_1.mp4
# El video 4673 ha sido procesado
# 50240_1.mp4
# El video 4674 ha sido procesado
# 50241_4.mp4
# El video 4675 ha sido procesado
# 50242_3.mp4
# El video 4676 ha sido procesado
# 50246_4.mp4
# El video 4677 ha sido procesado
# 50247_2.mp4
# El video 4678 ha sido procesado
# 50248_1.mp4
# El video 4679 ha sido procesado
# 50249_1.mp4
# El video 4680 ha sido procesado
# 50250_3.mp4
# El video 4681 ha sido procesado
# 50252_1.mp4
# El video 4682 ha sido procesado
# 50253_1.mp4
# El video 4683 ha sido procesado
# 50256_5.mp4
# El video 4684 ha sido procesado
# 50258_5.mp4
# El video 4685 ha sido procesado
# 50259_7.mp4
# El video 4686 ha sido procesado
# 50261_1.mp4
# El video 4687 ha sido procesado
# 50262_4.mp4
# El video 4688 ha sido procesado
# 50263_1.mp4
# El video 4689 ha sido procesado
# 50264_2.mp4
# El video 4690 ha sido procesado
# 50265_3.mp4
# El video 4691 ha sido procesado
# 50267_1.mp4
# El video 4692 ha sido procesado
# 50269_3.mp4
# El video 4693 ha sido procesado
# 50271_6.mp4
# El video 4694 ha sido procesado
# 50273_2.mp4
# El video 4695 ha sido procesado
# 50277_1.mp4
# El video 4696 ha sido procesado
# 50278_1.mp4
# El video 4697 ha sido procesado
# 50279_1.mp4
# El video 4698 ha sido procesado
# 50280_3.mp4
# El video 4699 ha sido procesado
# 50282_4.mp4
# El video 4700 ha sido procesado
# 50284_1.mp4
# El video 4701 ha sido procesado
# 50286_1.mp4
# El video 4702 ha sido procesado
# 50288_1.mp4
# El video 4703 ha sido procesado
# 50293_2.mp4
# El video 4704 ha sido procesado
# 50295_1.mp4
# El video 4705 ha sido procesado
# 50296_1.mp4
# El video 4706 ha sido procesado
# 50298_5.mp4
# El video 4707 ha sido procesado
# 50300_2.mp4
# El video 4708 ha sido procesado
# 50301_1.mp4
# El video 4709 ha sido procesado
# 50302_6.mp4
# El video 4710 ha sido procesado
# 50307_1.mp4
# El video 4711 ha sido procesado
# 50309_4.mp4
# El video 4712 ha sido procesado
# 50312_3.mp4
# El video 4713 ha sido procesado
# 50313_3.mp4
# El video 4714 ha sido procesado
# 50316_1.mp4
# El video 4715 ha sido procesado
# 50320_1.mp4
# El video 4716 ha sido procesado
# 50321_3.mp4
# El video 4717 ha sido procesado
# 50324_2.mp4
# El video 4718 ha sido procesado
# 50325_1.mp4
# El video 4719 ha sido procesado
# 50326_1.mp4
# El video 4720 ha sido procesado
# 50327_12.mp4
# El video 4721 ha sido procesado
# 50330_2.mp4
# El video 4722 ha sido procesado
# 50331_4.mp4
# El video 4723 ha sido procesado
# 50334_12.mp4
# El video 4724 ha sido procesado
# 50335_2.mp4
# El video 4725 ha sido procesado
# 50338_4.mp4
# El video 4726 ha sido procesado
# 50342_3.mp4
# El video 4727 ha sido procesado
# 50343_1.mp4
# El video 4728 ha sido procesado
# 50346_1.mp4
# El video 4729 ha sido procesado
# 50347_1.mp4
# El video 4730 ha sido procesado
# 50348_1.mp4
# El video 4731 ha sido procesado
# 50349_6.mp4
# El video 4732 ha sido procesado
# 50351_5.mp4
# El video 4733 ha sido procesado
# 50352_2.mp4
# El video 4734 ha sido procesado
# 50356_1.mp4
# El video 4735 ha sido procesado
# 50357_1.mp4
# El video 4736 ha sido procesado
# 50359_2.mp4
# El video 4737 ha sido procesado
# 50360_2.mp4
# El video 4738 ha sido procesado
# 50361_2.mp4
# El video 4739 ha sido procesado
# 50363_1.mp4
# El video 4740 ha sido procesado
# 50366_2.mp4
# El video 4741 ha sido procesado
# 50367_4.mp4
# El video 4742 ha sido procesado
# 50368_4.mp4
# El video 4743 ha sido procesado
# 50370_3.mp4
# El video 4744 ha sido procesado
# 50372_1.mp4
# El video 4745 ha sido procesado
# 50373_5.mp4
# El video 4746 ha sido procesado
# 50377_5.mp4
# El video 4747 ha sido procesado
# 50378_5.mp4
# El video 4748 ha sido procesado
# 50379_1.mp4
# El video 4749 ha sido procesado
# 50380_1.mp4
# El video 4750 ha sido procesado
# 50381_2.mp4
# El video 4751 ha sido procesado
# 50382_6.mp4
# El video 4752 ha sido procesado
# 50384_2.mp4
# El video 4753 ha sido procesado
# 50386_3.mp4
# El video 4754 ha sido procesado
# 50387_3.mp4
# El video 4755 ha sido procesado
# 50395_2.mp4
# El video 4756 ha sido procesado
# 50396_1.mp4
# El video 4757 ha sido procesado
# 50397_1.mp4
# El video 4758 ha sido procesado
# 50398_1.mp4
# El video 4759 ha sido procesado
# 50399_1.mp4
# El video 4760 ha sido procesado
# 50400_2.mp4
# El video 4761 ha sido procesado
# 50401_3.mp4
# El video 4762 ha sido procesado
# 50404_1.mp4
# El video 4763 ha sido procesado
# 50406_1.mp4
# El video 4764 ha sido procesado
# 50407_1.mp4
# El video 4765 ha sido procesado
# 50410_2.mp4
# El video 4766 ha sido procesado
# 50413_5.mp4
# El video 4767 ha sido procesado
# 50414_1.mp4
# El video 4768 ha sido procesado
# 50416_3.mp4
# El video 4769 ha sido procesado
# 50417_2.mp4
# El video 4770 ha sido procesado
# 50419_3.mp4
# El video 4771 ha sido procesado
# 50421_1.mp4
# El video 4772 ha sido procesado
# 50423_5.mp4
# El video 4773 ha sido procesado
# 50424_1.mp4
# El video 4774 ha sido procesado
# 50426_5.mp4
# El video 4775 ha sido procesado
# 50427_1.mp4
# El video 4776 ha sido procesado
# 50428_1.mp4
# El video 4777 ha sido procesado
# 50429_3.mp4
# El video 4778 ha sido procesado
# 50430_7.mp4
# El video 4779 ha sido procesado
# 50431_1.mp4
# El video 4780 ha sido procesado
# 50433_5.mp4
# El video 4781 ha sido procesado
# 50434_5.mp4
# El video 4782 ha sido procesado
# 50435_1.mp4
# El video 4783 ha sido procesado
# 50436_1.mp4
# El video 4784 ha sido procesado
# 50438_3.mp4
# El video 4785 ha sido procesado
# 50440_1.mp4
# El video 4786 ha sido procesado
# 50442_2.mp4
# El video 4787 ha sido procesado
# 50443_2.mp4
# El video 4788 ha sido procesado
# 50444_1.mp4
# El video 4789 ha sido procesado
# 50446_5.mp4
# El video 4790 ha sido procesado
# 50451_1.mp4
# El video 4791 ha sido procesado
# 50453_1.mp4
# El video 4792 ha sido procesado
# 50454_2.mp4
# El video 4793 ha sido procesado
# 50455_3.mp4
# El video 4794 ha sido procesado
# 50456_4.mp4
# El video 4795 ha sido procesado
# 50460_1.mp4
# El video 4796 ha sido procesado
# 50462_7.mp4
# El video 4797 ha sido procesado
# 50463_2.mp4
# El video 4798 ha sido procesado
# 50471_3.mp4
# El video 4799 ha sido procesado
# 50472_1.mp4
# El video 4800 ha sido procesado
# 50473_7.mp4
# El video 4801 ha sido procesado
# 50481_9.mp4
# El video 4802 ha sido procesado
# 50482_4.mp4
# El video 4803 ha sido procesado
# 50483_1.mp4
# El video 4804 ha sido procesado
# 50484_3.mp4
# El video 4805 ha sido procesado
# 50488_3.mp4
# El video 4806 ha sido procesado
# 50489_2.mp4
# El video 4807 ha sido procesado
# 50491_12.mp4
# El video 4808 ha sido procesado
# 50492_2.mp4
# El video 4809 ha sido procesado
# 50494_2.mp4
# El video 4810 ha sido procesado
# 50497_1.mp4
# El video 4811 ha sido procesado
# 50499_1.mp4
# El video 4812 ha sido procesado
# 50500_1.mp4
# El video 4813 ha sido procesado
# 50501_2.mp4
# El video 4814 ha sido procesado
# 50502_5.mp4
# El video 4815 ha sido procesado
# 50504_8.mp4
# El video 4816 ha sido procesado
# 50505_2.mp4
# El video 4817 ha sido procesado
# 50506_1.mp4
# El video 4818 ha sido procesado
# 50508_1.mp4
# El video 4819 ha sido procesado
# 50509_7.mp4
# El video 4820 ha sido procesado
# 50510_1.mp4
# El video 4821 ha sido procesado
# 50511_2.mp4
# El video 4822 ha sido procesado
# 50512_1.mp4
# El video 4823 ha sido procesado
# 50514_3.mp4
# El video 4824 ha sido procesado
# 50515_2.mp4
# El video 4825 ha sido procesado
# 50516_2.mp4
# El video 4826 ha sido procesado
# 50517_4.mp4
# El video 4827 ha sido procesado
# 50520_5.mp4
# El video 4828 ha sido procesado
# 50522_4.mp4
# El video 4829 ha sido procesado
# 50524_1.mp4
# El video 4830 ha sido procesado
# 50528_1.mp4
# El video 4831 ha sido procesado
# 50529_1.mp4
# El video 4832 ha sido procesado
# 50530_1.mp4
# El video 4833 ha sido procesado
# 50534_16.mp4
# El video 4834 ha sido procesado
# 50535_4.mp4
# El video 4835 ha sido procesado
# 50537_1.mp4
# El video 4836 ha sido procesado
# 50538_6.mp4
# El video 4837 ha sido procesado
# 50539_4.mp4
# El video 4838 ha sido procesado
# 50540_3.mp4
# El video 4839 ha sido procesado
# 50541_4.mp4
# El video 4840 ha sido procesado
# 50542_12.mp4
# El video 4841 ha sido procesado
# 50544_3.mp4
# El video 4842 ha sido procesado
# 50546_10.mp4
# El video 4843 ha sido procesado
# 50549_1.mp4
# El video 4844 ha sido procesado
# 50550_1.mp4
# El video 4845 ha sido procesado
# 50551_10.mp4
# El video 4846 ha sido procesado
# 50552_2.mp4
# El video 4847 ha sido procesado
# 50553_1.mp4
# El video 4848 ha sido procesado
# 50554_8.mp4
# El video 4849 ha sido procesado
# 50557_2.mp4
# El video 4850 ha sido procesado
# 50559_2.mp4
# El video 4851 ha sido procesado
# 50560_3.mp4
# El video 4852 ha sido procesado
# 50561_1.mp4
# El video 4853 ha sido procesado
# 50563_2.mp4
# El video 4854 ha sido procesado
# 50564_1.mp4
# El video 4855 ha sido procesado
# 50565_3.mp4
# El video 4856 ha sido procesado
# 50566_1.mp4
# El video 4857 ha sido procesado
# 50570_6.mp4
# El video 4858 ha sido procesado
# 50571_4.mp4
# El video 4859 ha sido procesado
# 50573_1.mp4
# El video 4860 ha sido procesado
# 50575_2.mp4
# El video 4861 ha sido procesado
# 50577_1.mp4
# El video 4862 ha sido procesado
# 50578_5.mp4
# El video 4863 ha sido procesado
# 50579_2.mp4
# El video 4864 ha sido procesado
# 50581_2.mp4
# El video 4865 ha sido procesado
# 50582_2.mp4
# El video 4866 ha sido procesado
# 50583_5.mp4
# El video 4867 ha sido procesado
# 50585_6.mp4
# El video 4868 ha sido procesado
# 50587_1.mp4
# El video 4869 ha sido procesado
# 50588_2.mp4
# El video 4870 ha sido procesado
# 50590_2.mp4
# El video 4871 ha sido procesado
# 50591_1.mp4
# El video 4872 ha sido procesado
# 50592_1.mp4
# El video 4873 ha sido procesado
# 50595_1.mp4
# El video 4874 ha sido procesado
# 50597_5.mp4
# El video 4875 ha sido procesado
# 50598_1.mp4
# El video 4876 ha sido procesado
# 50599_3.mp4
# El video 4877 ha sido procesado
# 50600_3.mp4
# El video 4878 ha sido procesado
# 50601_2.mp4
# El video 4879 ha sido procesado
# 50602_2.mp4
# El video 4880 ha sido procesado
# 50603_1.mp4
# El video 4881 ha sido procesado
# 50604_3.mp4
# El video 4882 ha sido procesado
# 50605_2.mp4
# El video 4883 ha sido procesado
# 50606_1.mp4
# El video 4884 ha sido procesado
# 50610_3.mp4
# El video 4885 ha sido procesado
# 50611_3.mp4
# El video 4886 ha sido procesado
# 50613_1.mp4
# El video 4887 ha sido procesado
# 50616_5.mp4
# El video 4888 ha sido procesado
# 50617_2.mp4
# El video 4889 ha sido procesado
# 50619_4.mp4
# El video 4890 ha sido procesado
# 50621_1.mp4
# El video 4891 ha sido procesado
# 50622_1.mp4
# El video 4892 ha sido procesado
# 50624_5.mp4
# El video 4893 ha sido procesado
# 50627_1.mp4
# El video 4894 ha sido procesado
# 50628_3.mp4
# El video 4895 ha sido procesado
# 50630_2.mp4
# El video 4896 ha sido procesado
# 50633_1.mp4
# El video 4897 ha sido procesado
# 50635_1.mp4
# El video 4898 ha sido procesado
# 50636_2.mp4
# El video 4899 ha sido procesado
# 50639_8.mp4
# El video 4900 ha sido procesado
# 50640_3.mp4
# El video 4901 ha sido procesado
# 50644_2.mp4
# El video 4902 ha sido procesado
# 50650_1.mp4
# El video 4903 ha sido procesado
# 50651_4.mp4
# El video 4904 ha sido procesado
# 50652_2.mp4
# El video 4905 ha sido procesado
# 50653_1.mp4
# El video 4906 ha sido procesado
# 50655_5.mp4
# El video 4907 ha sido procesado
# 50656_1.mp4
# El video 4908 ha sido procesado
# 50701_1.mp4
# El video 4909 ha sido procesado
# 50703_1.mp4
# El video 4910 ha sido procesado
# 50705_1.mp4
# El video 4911 ha sido procesado
# 50706_1.mp4
# El video 4912 ha sido procesado
# 50708_1.mp4
# El video 4913 ha sido procesado
# 50709_3.mp4
# El video 4914 ha sido procesado
# 50710_1.mp4
# El video 4915 ha sido procesado
# 50712_3.mp4
# El video 4916 ha sido procesado
# 50713_1.mp4
# El video 4917 ha sido procesado
# 50715_1.mp4
# El video 4918 ha sido procesado
# 50717_1.mp4
# El video 4919 ha sido procesado
# 50719_4.mp4
# El video 4920 ha sido procesado
# 50721_11.mp4
# El video 4921 ha sido procesado
# 50723_2.mp4
# El video 4922 ha sido procesado
# 50738_1.mp4
# El video 4923 ha sido procesado
# 50740_2.mp4
# El video 4924 ha sido procesado
# 50743_4.mp4
# El video 4925 ha sido procesado
# 50745_1.mp4
# El video 4926 ha sido procesado
# 50747_1.mp4
# El video 4927 ha sido procesado
# 50748_5.mp4
# El video 4928 ha sido procesado
# 50749_4.mp4
# El video 4929 ha sido procesado
# 50750_1.mp4
# El video 4930 ha sido procesado
# 50751_1.mp4
# El video 4931 ha sido procesado
# 50752_4.mp4
# El video 4932 ha sido procesado
# 50756_1.mp4
# El video 4933 ha sido procesado
# 50758_1.mp4
# El video 4934 ha sido procesado
# 50759_2.mp4
# El video 4935 ha sido procesado
# 50760_1.mp4
# El video 4936 ha sido procesado
# 50763_3.mp4
# El video 4937 ha sido procesado
# 50764_5.mp4
# El video 4938 ha sido procesado
# 50765_6.mp4
# El video 4939 ha sido procesado
# 50766_1.mp4
# El video 4940 ha sido procesado
# 50767_3.mp4
# El video 4941 ha sido procesado
# 50769_3.mp4
# El video 4942 ha sido procesado
# 50772_5.mp4
# El video 4943 ha sido procesado
# 50775_1.mp4
# El video 4944 ha sido procesado
# 50777_1.mp4
# El video 4945 ha sido procesado
# 50778_4.mp4
# El video 4946 ha sido procesado
# 50779_1.mp4
# El video 4947 ha sido procesado
# 50780_1.mp4
# El video 4948 ha sido procesado
# 50783_1.mp4
# El video 4949 ha sido procesado
# 50784_4.mp4
# El video 4950 ha sido procesado
# 50786_2.mp4
# El video 4951 ha sido procesado
# 50787_4.mp4
# El video 4952 ha sido procesado
# 50788_6.mp4
# El video 4953 ha sido procesado
# 50790_1.mp4
# El video 4954 ha sido procesado
# 50794_3.mp4
# El video 4955 ha sido procesado
# 50795_3.mp4
# El video 4956 ha sido procesado
# 50796_3.mp4
# El video 4957 ha sido procesado
# 50800_1.mp4
# El video 4958 ha sido procesado
# 50801_2.mp4
# El video 4959 ha sido procesado
# 50802_3.mp4
# El video 4960 ha sido procesado
# 50803_1.mp4
# El video 4961 ha sido procesado
# 50804_5.mp4
# El video 4962 ha sido procesado
# 50805_1.mp4
# El video 4963 ha sido procesado
# 50807_3.mp4
# El video 4964 ha sido procesado
# 50809_1.mp4
# El video 4965 ha sido procesado
# 50812_3.mp4
# El video 4966 ha sido procesado
# 50813_1.mp4
# El video 4967 ha sido procesado
# 50816_3.mp4
# El video 4968 ha sido procesado
# 50818_5.mp4
# El video 4969 ha sido procesado

# %% [markdown]
# # Add and Check Augmentations

# %%
class PlotVideos:
    def __init__(self, input_path, total = 1000):
        super(PlotVideos, self).__init__()
        self.input_path = input_path
        with open(os.path.join(self.input_path, 'ohp_ssl_boxes_16.json'), 'r') as file_object:
            self.boxes = json.load(file_object)
        self.videos = []
        self.total = total
        self.get_list()

    def get_list(self):
        path = os.path.join(self.input_path,"Images")
        videos = os.listdir(path)
        videos.sort()
        for video_name in videos[:self.total]:
            self.videos.append(os.path.join(path,video_name))
    
    def denormalise(self, image):
        #image = image.numpy().transpose(1, 2, 0)  # PIL images have channel last
        mean = [0.485, 0.456, 0.406]
        stdd = [0.229, 0.224, 0.225]
        image = (image * stdd + mean).clip(0, 1)
        image = cv2.resize(image, (480,480), interpolation = cv2.INTER_AREA)
        return image
    
    def transform_boxes(self, boxes, crop_size=(225, 225), frame_width=480, frame_height=480, flip_horizontal = True):
        adjusted_boxes = []
        for box in boxes:
            box = box.clone()  # Realizar una copia para evitar modificar la caja original
            crop_width, crop_height = crop_size

            # Ajustar la posición x e y de la caja para el RandomCrop
            box[:, 0::2] = np.maximum(0, box[:, 0::2] - crop_width)
            box[:, 1::2] = np.maximum(0, box[:, 1::2] - crop_height)

            # Supongamos que flip_horizontal es True si se aplicó una inversión horizontal    
            if flip_horizontal:
                box[:, 0::2] = np.maximum(0, crop_width - box[:, 0::2])  # Reflejar respecto al eje vertical

            # Supongamos que frame_width y frame_height son las dimensiones originales de los frames
            box[:, 0::2] = np.minimum(box[:, 0::2], frame_width - crop_width)
            box[:, 1::2] = np.minimum(box[:, 1::2], frame_height - crop_height)

            adjusted_boxes.append(box)
        return adjusted_boxes

    def plot_sync_videos(self, idx):
        f_h_anchor, f_h_positive, s_h_negative, box_anc, box_pos, box_neg = self.__getitem__(idx)
        #b1, b2, b3 = self.load_boxes(idx)
        h,w,_ = f_h_anchor[0].shape
        
        box_anc_ = []
        box_pos_ = []
        box_neg_ = []

        for i in range(16):
            box_anc_1 = [box_anc[i][0], box_anc[i][1], box_anc[i][4], box_anc[i][5]]
            box_pos_1 = [box_pos[i][0], box_pos[i][1], box_pos[i][4], box_pos[i][5]]
            box_neg_1 = [box_neg[i][0], box_neg[i][1], box_neg[i][4], box_neg[i][5]]
            box_anc_.append(box_anc_1)
            box_pos_.append(box_pos_1)
            box_neg_.append(box_neg_1)

        shift = np.random.randint(0, 25)
        f_h_anchor_aug, box_anc_ = self.add_video_transforms(copy.deepcopy(f_h_anchor), box_anc_, shift)
        s_h_negative_aug, box_pos_ = self.add_video_transforms(copy.deepcopy(s_h_negative), box_pos_, shift)
        f_h_positive_aug, box_neg_ = self.add_video_transforms(copy.deepcopy(f_h_positive), box_neg_, shift)
        
        #print(f_h_anchor)
        for i in range(16):
            #print(np.array(box_anc)[0])
            print(np.array(f_h_anchor_aug[0]).shape)
            #print(box_anc[i].x1)
            puntos1 = box_anc_[i]
            puntos2 = box_pos_[i]
            puntos3 = box_neg_[i]
            
            anc = np.ascontiguousarray(f_h_anchor_aug[i], dtype=np.uint8)
            neg = np.ascontiguousarray(s_h_negative_aug[i], dtype=np.uint8)
            pos = np.ascontiguousarray(f_h_positive_aug[i], dtype=np.uint8)

            

            #    img = np.ascontiguousarray(img, )

            
            cv2.rectangle(anc,(int(puntos1.x1), int(puntos1.y1)), (int(puntos1.x2), int(puntos1.y2)), (0,255,0), 2)
            cv2.rectangle(pos,(int(puntos2.x1), int(puntos2.y1)), (int(puntos2.x2), int(puntos2.y2)), (0,255,0), 2)
            cv2.rectangle(neg,(int(puntos3.x1), int(puntos3.y1)), (int(puntos3.x2), int(puntos3.y2)), (0,255,0), 2)

            #cv2.rectangle(anc,(int(puntos1[0]), int(puntos1[1])), (int(puntos1[2]), int(puntos1[3])), (0,255,0), 2)
            #cv2.rectangle(pos,(int(puntos2[0]), int(puntos2[1])), (int(puntos2[2]), int(puntos2[3])), (0,255,0), 2)
            #cv2.rectangle(neg,(int(puntos3[0]), int(puntos3[1])), (int(puntos3[2]), int(puntos3[3])), (0,255,0), 2)

            frame = np.hstack((anc, pos, neg))
            clear_output(wait=True)
            plt.imshow(frame)
            plt.show()
            time.sleep(1)

    def temporal_shift(self, frames, boxes, shift_amount=3):
        return frames[shift_amount:] + frames[:shift_amount], boxes[shift_amount:] + boxes[:shift_amount]
    
    def RandomHorizontalFlip(self, clip, bboxes):
        h,w,c = clip[0].shape
        points_2d = np.reshape(bboxes, (-1, 2))
        points_2d[:, 0] = w - points_2d[:, 0]
        adjusted_points = points_2d.flatten()
        return adjusted_points
        

    def apply_channel_shuffle(self,images, random_state, parents, hooks):
        num_channels = 3  # Suponiendo que tienes imágenes RGB con 3 canales (R, G, B)
        channel_permutation = np.random.permutation(num_channels)
        return [image[:, :, channel_permutation] for image in images]
    
    def keypoint_func(self,keypoints_on_images, random_state, parents, hooks):
        return keypoints_on_images

    def add_video_transforms(self, frames, boxes, shift_amount):
        frames, boxes = self.temporal_shift(frames, boxes, shift_amount)
        bbs_ = []
        for i in range(16):
            bbs_.append(BoundingBox(x1=boxes[i][0], y1=boxes[i][1], x2=boxes[i][2], y2=boxes[i][3]))
        bbs = BoundingBoxesOnImage(bbs_, shape=frames[0].shape)
        rotation_angle = np.random.randint(-25, 25)
        sigma_value  = np.random.uniform(0, 1.0) 
        num_channels = 3  # Suponiendo que tienes imágenes RGB con 3 canales (R, G, B)
        channel_permutation = np.random.permutation(num_channels)
        saturation = np.random.randint(0,50)
        translate = np.random.randint(-20,20)
        scale_factor = 1.2

        video_augmenter = iaa.Sequential([
            #iaa.AssertShape((None, 480, 480, 3)),
            iaa.Fliplr(p=0.5),
            #iaa.ChannelShuffle(),
            iaa.CoarseDropout((0.1, 0.15), size_percent=(0.03, 0.03)),
            iaa.WithHueAndSaturation(
                iaa.WithChannels(0, iaa.Add(saturation))
            ),
            iaa.Lambda(self.apply_channel_shuffle, self.keypoint_func),  # Aplica la permutación a todos los frames
            iaa.Affine(rotate=(rotation_angle), scale=scale_factor),
            iaa.TranslateX(px=translate),  # Rotación en el rango de -25 a 25 grados
            iaa.GaussianBlur(sigma=sigma_value),  # Desenfoque gaussiano
             #Does not work
        ], random_order=False)

        # Aplicar las augmentations a todos los frames y bounding boxes
        video_, boxes_ = video_augmenter(images=frames, bounding_boxes=bbs)
        return video_, boxes_
    
    def load_boxes(self, idx):
        video_path = self.videos[idx]
        name = video_path.split('/')[-1]
        b1 = self.boxes[name+"_f_h"]
        b2 = self.boxes[name+"_s_h"]
        return b1,b2,b1
    
    def load_video(self,path, add_augmentations = False):
        transform = transforms.Compose([transforms.CenterCrop(H), transforms.ToTensor(),
                                        transforms.Normalize(mean=[0.485, 0.456, 0.406], 
                                        std=[0.229, 0.224, 0.225])])
        files = os.listdir(path)
        files.sort(key=lambda x: int(x.split('.')[0]))
        #images = torch.zeros(num_frames, C, 480, 480)
        images = []
        for i, name in enumerate(files):
            path_to_image = path+"/"+name
            image = cv2.imread(path_to_image)
            im_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
            images.append(im_rgb)
        return images
    
    def __getitem__(self, idx):
        video_path = self.videos[idx]
        path_fh = os.path.join(video_path, "f_h")
        path_sh = os.path.join(video_path, "s_h")
        f1 = self.load_video(path_fh)
        f2 = self.load_video(path_sh)
        f3 = self.load_video(path_fh, add_augmentations=True)
        b1, b2, b3 = self.load_boxes(idx)
        #boxes1 = torch.tensor(b1)  # [16,8]
        #boxes2 = torch.tensor(b2)
        #boxes3 = torch.tensor(b3)
        
        boxes1 = list(b1)
        boxes2 = list(b2)
        boxes3 = list(b3)
        return f1, f3, f2, boxes1, boxes3, boxes2

# %%
input_path = "./OHP_Unlabeled/"
transformations = PlotVideos(input_path)
transformations.plot_sync_videos(30)
